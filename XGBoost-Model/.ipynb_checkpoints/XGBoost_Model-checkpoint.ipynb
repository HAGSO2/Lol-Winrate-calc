# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\usuario\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\usuario\anaconda3\lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\users\usuario\anaconda3\lib\site-packages (from xgboost) (1.16.3)

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

from xgboost import XGBClassifier

# %%
xgb_df = pd.read_csv("../XGBoost-Model/Model_data/worlds_xgb_dataset.csv")

xgb_df.head()
# Out:
#    winrate_diff  gold15_diff  xp15_diff  cs15_diff  dragon_diff  baron_diff  \
# 0     -1.000000          0.0        0.0        0.0    -3.000000   -1.000000
# 1     -1.000000          0.0        0.0        0.0    -1.500000   -1.000000
# 2     -1.000000          0.0        0.0        0.0    -1.000000   -1.000000
# 3      0.000000          0.0        0.0        0.0     0.000000    0.500000
# 4     -0.333333          0.0        0.0        0.0    -1.333333   -0.666667
#
#    tower_diff  target
# 0   -6.000000       0
# 1   -8.000000       0
# 2   -5.000000       1
# 3    1.000000       1
# 4   -2.333333       0

# %%
X = xgb_df.drop(columns=["target"])

y = xgb_df["target"]


print(X.shape)
print(y.shape)
# Out:
# (9764, 7)
# (9764,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (7811, 7)
# (1953, 7)

# %%
model = XGBClassifier(
    objective="binary:logistic",

    n_estimators=300,

    learning_rate=0.05,

    max_depth=4,

    subsample=0.8,

    colsample_bytree=0.8,

    random_state=42
)

# %%
model.fit(
    X_train,
    y_train
)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
pred = model.predict(X_test)

proba = model.predict_proba(X_test)[:,1]

# %%
print("Accuracy :", accuracy_score(y_test, pred))
print("Precision:", precision_score(y_test, pred))
print("Recall   :", recall_score(y_test, pred))
print("F1 Score :", f1_score(y_test, pred))
print("ROC AUC  :", roc_auc_score(y_test, proba))
# Out:
# Accuracy : 0.6395289298515104
# Precision: 0.6416131989000916
# Recall   : 0.6910167818361304
# F1 Score : 0.6653992395437263
# ROC AUC  : 0.6735575812312281

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(
    y_test,
    pred
)

cm
# Out:
# array([[549, 391],
#        [313, 700]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, pred)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.xlabel("Predicción")
plt.ylabel("Real")

plt.show()

# %%
print(classification_report(
    y_test,
    pred
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.58      0.61       940
#            1       0.64      0.69      0.67      1013
#
#     accuracy                           0.64      1953
#    macro avg       0.64      0.64      0.64      1953
# weighted avg       0.64      0.64      0.64      1953

# %%
importance = pd.DataFrame({

    "Feature": X.columns,

    "Importance": model.feature_importances_

})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

print(importance)
# Out:
#         Feature  Importance
# 0  winrate_diff    0.241549
# 6    tower_diff    0.180822
# 3     cs15_diff    0.154516
# 1   gold15_diff    0.114193
# 4   dragon_diff    0.107467
# 2     xp15_diff    0.101902
# 5    baron_diff    0.099552

# %%
plt.figure(figsize=(8,6))

sns.barplot(
    data=importance,
    x="Importance",
    y="Feature"
)

plt.show()

# %%
proba = model.predict_proba(X_test)

proba[:10]
# Out:
# array([[0.5100962 , 0.4899038 ],
#        [0.62598103, 0.37401897],
#        [0.6270077 , 0.37299228],
#        [0.52086216, 0.47913784],
#        [0.54237545, 0.45762458],
#        [0.794726  , 0.20527397],
#        [0.490749  , 0.509251  ],
#        [0.33041286, 0.66958714],
#        [0.52235377, 0.4776462 ],
#        [0.6326482 , 0.36735174]], dtype=float32)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=8,
    min_samples_split=5,
    min_samples_leaf=2,
    random_state=30,
    n_jobs=-1
)

# %%
rf_model.fit(
    X_train,
    y_train
)
# Out:
# RandomForestClassifier(max_depth=8, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=300, n_jobs=-1, random_state=30)

# %%
pred = rf_model.predict(X_test)

proba = rf_model.predict_proba(X_test)[:,1]

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

print("Accuracy :", accuracy_score(y_test, pred))
print("Precision:", precision_score(y_test, pred))
print("Recall   :", recall_score(y_test, pred))
print("F1 Score :", f1_score(y_test, pred))
print("ROC AUC  :", roc_auc_score(y_test, proba))
# Out:
# Accuracy : 0.6333845366103431
# Precision: 0.6346328195829556
# Recall   : 0.6910167818361304
# F1 Score : 0.6616257088846881
# ROC AUC  : 0.6834996114343324

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[537 403]
#  [313 700]]

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf_model.feature_importances_
})

importance.sort_values(
    "Importance",
    ascending=False
)
# Out:
#         Feature  Importance
# 0  winrate_diff    0.210100
# 6    tower_diff    0.193216
# 3     cs15_diff    0.150436
# 1   gold15_diff    0.145063
# 2     xp15_diff    0.118960
# 4   dragon_diff    0.097531
# 5    baron_diff    0.084694

# %%
import joblib

joblib.dump(
    model,
    "worlds_xgb_model.pkl"
)
# Out:
# ['worlds_xgb_model.pkl']

# %%
model = joblib.load(
    "worlds_xgb_model.pkl"
)
