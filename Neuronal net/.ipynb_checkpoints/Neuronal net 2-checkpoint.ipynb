# %% [raw]
# pip install tensorflow

# %%
import numpy as np
import pandas as pd
from calc_rates2 import calc_rates
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.metrics import AUC

print('TensorFlow:', tf.__version__)
# Out:
# TensorFlow: 2.21.0

# %% [raw]
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# # Leer todos los archivos
# dfs = []
# lens = []
# #Los primeros años tienen algunas carencias de datos y 2021 es un año con muchos.
# for year in range(2014,2027):
#     df = pd.read_csv(f"../Data/Procesed data/Re-formulated data/{year}_LoL_esports_match_data_from_OraclesElixir.csv",low_memory=False)
#     lens.append(len(df))
#     dfs.append(df)
# # [2014, 2015, 2016,  2017,  2018,  2019,  2020,  2021,  2022,  2023,  2024,  2025,  2026]
# # [1836, 3630, 8428, 11010, 13472, 16250, 19494, 24604, 25058, 22212, 20390, 20082, 12508]
# # | -      -    -    [train                          ][val         ] [test              ]
# # print(lens)
#
# complete_set  = pd.concat(dfs, ignore_index=True)
# complete_set = calc_rates(complete_set)
#
# index_train = sum(lens[i] for i in range(3))
# index_val = sum(lens[i] for i in range(8))
# index_test = sum(lens[i] for i in range(10))
#
# print("Train: ",index_val-index_train)
# print("Val: ",index_test-index_val)
# print("Test: ",len(complete_set)-index_test)
#
# train_set = complete_set[index_train:index_val]
# val_set = complete_set[index_val:index_test]
# test_set = complete_set[index_test:]
#
# train_set.to_csv("../Data/Net/train_data2.csv",index=False)
# val_set.to_csv("../Data/Net/val_data2.csv",index=False)
# test_set.to_csv("../Data/Net/test_data2.csv",index=False)

# %%
train_set = pd.read_csv("../Data/Net/train_data2.csv")
val_set = pd.read_csv("../Data/Net/val_data2.csv")
test_set = pd.read_csv("../Data/Net/test_data2.csv")

# %% [markdown]
# # Poda de columnas y datos

# %%
def remove_labels(df, label_name):
    X = df.drop(label_name, axis=1)
    y = df[label_name].copy()
    return (X, y)

# %%
X_train, y_train = remove_labels(train_set, 'result')
X_val, y_val = remove_labels(val_set, 'result')
X_test, y_test = remove_labels(test_set, 'result')

# %%
assert(len(X_train) == len(y_train))
print("Entrenamiento:",len(X_train))

assert(len(X_val) == len(y_val))
print("Val:",len(X_val))

assert(len(X_test) == len(y_test))
print("Prueba:",len(X_test))
# Out:
# Entrenamiento: 84830
# Val: 47270
# Prueba: 52980

# %%
columnas_equipo_mudas = ["side","goldat10","goldat15","xpat10","xpat15","avg_dragons_team","avg_barons_team","avg_heralds_team","avg_towers_team","avg_dragons_vs_opp","avg_barons_vs_opp","avg_heralds_vs_opp","avg_towers_vs_opp","wins_vs_opponent"]

# %%
X_train_team = X_train[columnas_equipo_mudas]
X_val_team = X_val[columnas_equipo_mudas]
X_test_team = X_test[columnas_equipo_mudas]

# %%
print("-"*35)
print(X_train_team.isnull().sum())
print("-"*35)
print(X_val_team.isnull().sum())
print("-"*35)
print(X_test_team.isnull().sum())
# Out:
# -----------------------------------
# side                0
# goldat10            0
# goldat15            0
# xpat10              0
# xpat15              0
# avg_dragons_team    0
# avg_barons_team     0
# avg_heralds_team    0
# avg_towers_team     0
# wins_vs_opponent    0
# dtype: int64
# -----------------------------------
# side                0
# goldat10            0
# goldat15            0
# xpat10              0
# xpat15              0
# avg_dragons_team    0
# avg_barons_team     0
# avg_heralds_team    0
# avg_towers_team     0
# wins_vs_opponent    0
# dtype: int64
# -----------------------------------
# side                0
# goldat10            0
# goldat15            0
# xpat10              0
# xpat15              0
# avg_dragons_team    0
# avg_barons_team     0
# avg_heralds_team    0
# avg_towers_team     0
# wins_vs_opponent    0
# dtype: int64

# %%
X_train_team.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 84830 entries, 0 to 84829
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   side              84830 non-null  bool
#  1   goldat10          84830 non-null  float64
#  2   goldat15          84830 non-null  float64
#  3   xpat10            84830 non-null  float64
#  4   xpat15            84830 non-null  float64
#  5   avg_dragons_team  84830 non-null  float64
#  6   avg_barons_team   84830 non-null  float64
#  7   avg_heralds_team  84830 non-null  float64
#  8   avg_towers_team   84830 non-null  float64
#  9   wins_vs_opponent  84830 non-null  int64
# dtypes: bool(1), float64(8), int64(1)
# memory usage: 5.9 MB

# %%
X_train_team.describe()
# Out:
#            goldat10      goldat15        xpat10        xpat15  \
# count  84830.000000  84830.000000  84830.000000  84830.000000
# mean   15517.999402  24504.939024  18335.084838  29338.922900
# std      954.798645   1820.033859    864.702961   1482.786239
# min    11201.000000  16960.000000  12097.000000  19693.000000
# 25%    14893.000000  23281.000000  17827.000000  28414.000000
# 50%    15441.000000  24256.000000  18395.000000  29392.525000
# 75%    16038.000000  25532.000000  18889.000000  30285.000000
# max    24250.000000  39960.000000  25294.000000  37356.000000
#
#        avg_dragons_team  avg_barons_team  avg_heralds_team  avg_towers_team  \
# count      84830.000000     84830.000000      84830.000000     84830.000000
# mean           1.873397         0.691629          0.510084         6.042087
# std            0.599981         0.213876          0.356368         1.461538
# min            0.000000         0.000000          0.000000         0.000000
# 25%            1.526667         0.605469          0.266667         5.442066
# 50%            1.911504         0.714286          0.459459         6.219178
# 75%            2.268794         0.804878          0.726316         6.920490
# max            6.000000         4.000000          2.000000        11.000000
#
#        wins_vs_opponent
# count      84830.000000
# mean           3.543157
# std            5.049577
# min            0.000000
# 25%            0.000000
# 50%            2.000000
# 75%            5.000000
# max           49.000000

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_team = pd.DataFrame(
    scaler.fit_transform(X_train_team),
    columns=X_train_team.columns,
    index=X_train_team.index)

X_val_team = pd.DataFrame(
    scaler.fit_transform(X_val_team),
    columns=X_val_team.columns,
    index=X_val_team.index)

X_test_team = pd.DataFrame(
    scaler.fit_transform(X_test_team),
    columns=X_test_team.columns,
    index=X_test_team.index)

# %%
X_train_team.describe()
# Out:
#                side      goldat10      goldat15        xpat10        xpat15  \
# count  84830.000000  8.483000e+04  8.483000e+04  8.483000e+04  8.483000e+04
# mean       0.000000  1.522436e-15  2.251490e-16 -3.248578e-15  4.181338e-16
# std        1.000006  1.000006e+00  1.000006e+00  1.000006e+00  1.000006e+00
# min       -1.000000 -4.521398e+00 -4.145518e+00 -7.214179e+00 -6.505307e+00
# 25%       -1.000000 -6.545915e-01 -6.724854e-01 -5.875866e-01 -6.237773e-01
# 50%        0.000000 -8.064512e-02 -1.367779e-01  6.929029e-02  3.614979e-02
# 75%        1.000000  5.446213e-01  5.643120e-01  6.405881e-01  6.380439e-01
# max        1.000000  9.145438e+00  8.491684e+00  8.047800e+00  5.406797e+00
#
#        avg_dragons_team  avg_barons_team  avg_heralds_team  avg_towers_team  \
# count      8.483000e+04     8.483000e+04      8.483000e+04     8.483000e+04
# mean       4.717407e-16    -7.076111e-16      3.430842e-16    -3.430842e-16
# std        1.000006e+00     1.000006e+00      1.000006e+00     1.000006e+00
# min       -3.122447e+00    -3.233797e+00     -1.431348e+00    -4.134086e+00
# 25%       -5.779055e-01    -4.028516e-01     -6.830538e-01    -4.105431e-01
# 50%        6.351523e-02     1.059358e-01     -1.420571e-01     1.211686e-01
# 75%        6.590198e-01     5.295117e-01      6.067697e-01     6.010169e-01
# max        6.877935e+00     1.546871e+01      4.180861e+00     3.392278e+00
#
#        wins_vs_opponent
# count      8.483000e+04
# mean       4.020518e-17
# std        1.000006e+00
# min       -7.016781e-01
# 25%       -7.016781e-01
# 50%       -3.056030e-01
# 75%        2.885096e-01
# max        9.002161e+00

# %% [markdown]
# # Red neuronal

# %%
print(X_train_team.shape)
print(y_train.unique())
# Out:
# (84830, 10)
# [1 0]

# %%
num_features = len(X_train_team.columns)

network_team = Sequential([
    # 1. Capa de Entrada (Dependerá de cuántas columnas numéricas te queden)
    Input(shape=(num_features,)), 
    
    # 2. Primer Bloque Oculto
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    
    # 3. Segundo Bloque Oculto
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    
    # 4. Tercer Bloque Oculto
    Dense(32, activation='relu'),
    Dropout(0.2),
    
    # 5. Capa de Salida
    Dense(1, activation='sigmoid') 
])

# %%
network_team.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │           1,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,545 (49.00 KB)
#  Trainable params: 12,161 (47.50 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
network_team.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy', AUC(name='auc')])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = network_team.fit(X_train_team, 
                      y_train, 
                      epochs=20, 
                      validation_data=(X_val_team, y_val))
# Out:
# Epoch 1/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6751 - auc: 0.7393 - loss: 0.6018 - val_accuracy: 0.6817 - val_auc: 0.7557 - val_loss: 0.5842
# Epoch 2/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6860 - auc: 0.7551 - loss: 0.5857 - val_accuracy: 0.6796 - val_auc: 0.7534 - val_loss: 0.5841
# Epoch 3/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6850 - auc: 0.7570 - loss: 0.5843 - val_accuracy: 0.6811 - val_auc: 0.7561 - val_loss: 0.5822
# Epoch 4/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6892 - auc: 0.7589 - loss: 0.5833 - val_accuracy: 0.6800 - val_auc: 0.7552 - val_loss: 0.5839
# Epoch 5/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6886 - auc: 0.7590 - loss: 0.5830 - val_accuracy: 0.6808 - val_auc: 0.7558 - val_loss: 0.5831
# Epoch 6/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6903 - auc: 0.7591 - loss: 0.5825 - val_accuracy: 0.6815 - val_auc: 0.7554 - val_loss: 0.5835
# Epoch 7/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6899 - auc: 0.7604 - loss: 0.5808 - val_accuracy: 0.6806 - val_auc: 0.7551 - val_loss: 0.5831
# Epoch 8/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6897 - auc: 0.7602 - loss: 0.5812 - val_accuracy: 0.6803 - val_auc: 0.7549 - val_loss: 0.5833
# Epoch 9/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6893 - auc: 0.7603 - loss: 0.5812 - val_accuracy: 0.6814 - val_auc: 0.7541 - val_loss: 0.5844
# Epoch 10/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6897 - auc: 0.7609 - loss: 0.5805 - val_accuracy: 0.6820 - val_auc: 0.7556 - val_loss: 0.5838
# Epoch 11/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6910 - auc: 0.7608 - loss: 0.5809 - val_accuracy: 0.6804 - val_auc: 0.7548 - val_loss: 0.5842
# Epoch 12/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6905 - auc: 0.7619 - loss: 0.5792 - val_accuracy: 0.6800 - val_auc: 0.7556 - val_loss: 0.5842
# Epoch 13/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6915 - auc: 0.7617 - loss: 0.5797 - val_accuracy: 0.6817 - val_auc: 0.7557 - val_loss: 0.5848
# Epoch 14/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6901 - auc: 0.7625 - loss: 0.5791 - val_accuracy: 0.6815 - val_auc: 0.7556 - val_loss: 0.5829
# Epoch 15/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6879 - auc: 0.7615 - loss: 0.5794 - val_accuracy: 0.6810 - val_auc: 0.7553 - val_loss: 0.5845
# Epoch 16/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6899 - auc: 0.7622 - loss: 0.5791 - val_accuracy: 0.6811 - val_auc: 0.7553 - val_loss: 0.5832
# Epoch 17/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6905 - auc: 0.7619 - loss: 0.5792 - val_accuracy: 0.6814 - val_auc: 0.7549 - val_loss: 0.5831
# Epoch 18/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6912 - auc: 0.7637 - loss: 0.5779 - val_accuracy: 0.6826 - val_auc: 0.7564 - val_loss: 0.5815
# Epoch 19/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6920 - auc: 0.7642 - loss: 0.5771 - val_accuracy: 0.6791 - val_auc: 0.7551 - val_loss: 0.5824
# Epoch 20/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6897 - auc: 0.7624 - loss: 0.5785 - val_accuracy: 0.6821 - val_auc: 0.7553 - val_loss: 0.5824
# Epoch 21/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6911 - auc: 0.7629 - loss: 0.5781 - val_accuracy: 0.6809 - val_auc: 0.7544 - val_loss: 0.5836
# Epoch 22/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.6910 - auc: 0.7633 - loss: 0.5777 - val_accuracy: 0.6814 - val_auc: 0.7551 - val_loss: 0.5833
# Epoch 23/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - accuracy: 0.6907 - auc: 0.7627 - loss: 0.5783 - val_accuracy: 0.6816 - val_auc: 0.7554 - val_loss: 0.5823
# Epoch 24/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6912 - auc: 0.7641 - loss: 0.5768 - val_accuracy: 0.6831 - val_auc: 0.7555 - val_loss: 0.5823
# Epoch 25/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6921 - auc: 0.7641 - loss: 0.5773 - val_accuracy: 0.6828 - val_auc: 0.7553 - val_loss: 0.5821
# Epoch 26/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6916 - auc: 0.7635 - loss: 0.5776 - val_accuracy: 0.6828 - val_auc: 0.7558 - val_loss: 0.5818
# Epoch 27/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6900 - auc: 0.7633 - loss: 0.5775 - val_accuracy: 0.6817 - val_auc: 0.7562 - val_loss: 0.5827
# Epoch 28/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6913 - auc: 0.7644 - loss: 0.5768 - val_accuracy: 0.6816 - val_auc: 0.7548 - val_loss: 0.5832
# Epoch 29/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6911 - auc: 0.7648 - loss: 0.5761 - val_accuracy: 0.6810 - val_auc: 0.7552 - val_loss: 0.5839
# Epoch 30/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6906 - auc: 0.7645 - loss: 0.5764 - val_accuracy: 0.6824 - val_auc: 0.7556 - val_loss: 0.5829
# Epoch 31/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.6921 - auc: 0.7650 - loss: 0.5762 - val_accuracy: 0.6820 - val_auc: 0.7557 - val_loss: 0.5826
# Epoch 32/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6906 - auc: 0.7646 - loss: 0.5764 - val_accuracy: 0.6818 - val_auc: 0.7549 - val_loss: 0.5842
# Epoch 33/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6924 - auc: 0.7651 - loss: 0.5757 - val_accuracy: 0.6825 - val_auc: 0.7554 - val_loss: 0.5825
# Epoch 34/50
# 1479/2651 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6954 - auc: 0.7671 - loss: 0.5743
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 history = network_team.fit(X_train_team,
#       2                       y_train,
#       3                       epochs=50,
#       4                       validation_data=(X_val_team, y_val))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\trainer.py:400, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     398 callbacks.on_train_batch_begin(begin_step)
#     399 logs = self.train_function(iterator)
# --> 400 callbacks.on_train_batch_end(end_step, logs)
#     401 if self.stop_training:
#     402     break
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\callbacks\callback_list.py:198, in CallbackList.on_train_batch_end(self, batch, logs)
#     196     self._async_dispatch(self._on_train_batch_end, batch, logs)
#     197 else:
# --> 198     self._on_train_batch_end(batch, logs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\callbacks\callback_list.py:220, in CallbackList._on_train_batch_end(self, batch, logs)
#     218 logs = python_utils.pythonify_logs(logs)
#     219 for callback in self.callbacks:
# --> 220     callback.on_train_batch_end(batch, logs=logs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\callbacks\progbar_logger.py:58, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#      57 def on_train_batch_end(self, batch, logs=None):
# ---> 58     self._update_progbar(batch, logs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\callbacks\progbar_logger.py:98, in ProgbarLogger._update_progbar(self, batch, logs)
#      95 self.seen = batch + 1  # One-indexed.
#      97 if self.verbose == 1:
# ---> 98     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\progbar.py:212, in Progbar.update(self, current, values, finalize)
#     209 if finalize:
#     210     message += "\n"
# --> 212 io_utils.print_msg(message, line_break=False)
#     213 self._prev_total_width = total_width
#     214 message = ""
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\io_utils.py:98, in print_msg(message, line_break)
#      96 message = f"{message}\n" if line_break else message
#      97 try:
# ---> 98     sys.stdout.write(message)
#      99 except UnicodeEncodeError:
#     100     # If the encoding differs from UTF-8, `sys.stdout.write` may fail.
#     101     # To address this, replace special unicode characters in the
#     102     # message, and then encode and decode using the target encoding.
#     103     message = _replace_special_unicode_character(message)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\iostream.py:760, in OutStream.write(self, string)
#     758     self.pub_thread.schedule(self._flush)
#     759 else:
# --> 760     self._schedule_flush()
#     762 return len(string)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\iostream.py:656, in OutStream._schedule_flush(self)
#     653 def _schedule_in_thread():
#     654     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 656 self.pub_thread.schedule(_schedule_in_thread)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\iostream.py:339, in IOPubThread.schedule(self, f)
#     337     self._events.append(f)
#     338     # wake event thread (message content is ignored)
# --> 339     self._event_pipe.send(b"")
#     340 else:
#     341     f()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\zmq\sugar\socket.py:698, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     691         data = zmq.Frame(
#     692             data,
#     693             track=track,
#     694             copy=copy or None,
#     695             copy_threshold=self.copy_threshold,
#     696         )
#     697     data.group = group
# --> 698 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/_zmq.py:1152
# -> 1152     def send(self, data, flags=0, copy: bint = True, track: bint = False):
#    1153         """
#    1154         Send a single zmq message frame on this socket.
#    1155
#
# File zmq/backend/cython/_zmq.py:1200
# -> 1200             return _send_copy(self.handle, data, flags)
#
# File zmq/backend/cython/_zmq.py:1468
# -> 1468             _check_rc(rc)
#
# File zmq/backend/cython/_zmq.py:179
# --> 179     PyErr_CheckSignals()
#
# KeyboardInterrupt:
