# %% [raw]
# pip install tensorflow

# %%
import numpy as np
import pandas as pd
from calc_rates2 import calc_rates
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.metrics import AUC

print('TensorFlow:', tf.__version__)
# Out:
# TensorFlow: 2.21.0

# %% [raw]
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# # Leer todos los archivos
# dfs = []
# lens = []
# #Los primeros años tienen algunas carencias de datos y 2021 es un año con muchos.
# for year in range(2014,2027):
#     df = pd.read_csv(f"../Data/Procesed data/Re-formulated data/{year}_LoL_esports_match_data_from_OraclesElixir.csv",low_memory=False)
#     lens.append(len(df))
#     dfs.append(df)
# # [2014, 2015, 2016,  2017,  2018,  2019,  2020,  2021,  2022,  2023,  2024,  2025,  2026]
# # [1836, 3630, 8428, 11010, 13472, 16250, 19494, 24604, 25058, 22212, 20390, 20082, 12508]
# # | -      -    -    [train                          ][val         ] [test              ]
# # print(lens)
#
# complete_set  = pd.concat(dfs, ignore_index=True)
# complete_set = calc_rates(complete_set)
#
# index_train = sum(lens[i] for i in range(3))
# index_val = sum(lens[i] for i in range(8))
# index_test = sum(lens[i] for i in range(10))
#
# print("Train: ",index_val-index_train)
# print("Val: ",index_test-index_val)
# print("Test: ",len(complete_set)-index_test)
#
# train_set = complete_set[index_train:index_val]
# val_set = complete_set[index_val:index_test]
# test_set = complete_set[index_test:]
#
# train_set.to_csv("../Data/Net/train_data2.csv",index=False)
# val_set.to_csv("../Data/Net/val_data2.csv",index=False)
# test_set.to_csv("../Data/Net/test_data2.csv",index=False)

# %%
train_set = pd.read_csv("../Data/Net/train_data2.csv")
val_set = pd.read_csv("../Data/Net/val_data2.csv")
test_set = pd.read_csv("../Data/Net/test_data2.csv")

# %% [markdown]
# # Poda de columnas y datos

# %%
def remove_labels(df, label_name):
    X = df.drop(label_name, axis=1)
    y = df[label_name].copy()
    return (X, y)

# %%
X_train, y_train = remove_labels(train_set, 'result')
X_val, y_val = remove_labels(val_set, 'result')
X_test, y_test = remove_labels(test_set, 'result')

# %%
assert(len(X_train) == len(y_train))
print("Entrenamiento:",len(X_train))

assert(len(X_val) == len(y_val))
print("Val:",len(X_val))

assert(len(X_test) == len(y_test))
print("Prueba:",len(X_test))
# Out:
# Entrenamiento: 84830
# Val: 47270
# Prueba: 52980

# %%
columnas_equipo_mudas = ["side","goldat10","goldat15","xpat10","xpat15","avg_dragons_team","avg_barons_team","avg_heralds_team","avg_towers_team","avg_dragons_vs_opp","avg_barons_vs_opp","avg_heralds_vs_opp","avg_towers_vs_opp","wins_vs_opponent"]

# %%
X_train_team = X_train[columnas_equipo_mudas]
X_val_team = X_val[columnas_equipo_mudas]
X_test_team = X_test[columnas_equipo_mudas]

# %%
print("-"*35)
print(X_train_team.isnull().sum())
print("-"*35)
print(X_val_team.isnull().sum())
print("-"*35)
print(X_test_team.isnull().sum())
# Out:
# -----------------------------------
# side                  0
# goldat10              0
# goldat15              0
# xpat10                0
# xpat15                0
# avg_dragons_team      0
# avg_barons_team       0
# avg_heralds_team      0
# avg_towers_team       0
# avg_dragons_vs_opp    0
# avg_barons_vs_opp     0
# avg_heralds_vs_opp    0
# avg_towers_vs_opp     0
# wins_vs_opponent      0
# dtype: int64
# -----------------------------------
# side                  0
# goldat10              0
# goldat15              0
# xpat10                0
# xpat15                0
# avg_dragons_team      0
# avg_barons_team       0
# avg_heralds_team      0
# avg_towers_team       0
# avg_dragons_vs_opp    0
# avg_barons_vs_opp     0
# avg_heralds_vs_opp    0
# avg_towers_vs_opp     0
# wins_vs_opponent      0
# dtype: int64
# -----------------------------------
# side                  0
# goldat10              0
# goldat15              0
# xpat10                0
# xpat15                0
# avg_dragons_team      0
# avg_barons_team       0
# avg_heralds_team      0
# avg_towers_team       0
# avg_dragons_vs_opp    0
# avg_barons_vs_opp     0
# avg_heralds_vs_opp    0
# avg_towers_vs_opp     0
# wins_vs_opponent      0
# dtype: int64

# %%
X_train_team.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 84830 entries, 0 to 84829
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   side                84830 non-null  bool
#  1   goldat10            84830 non-null  float64
#  2   goldat15            84830 non-null  float64
#  3   xpat10              84830 non-null  float64
#  4   xpat15              84830 non-null  float64
#  5   avg_dragons_team    84830 non-null  float64
#  6   avg_barons_team     84830 non-null  float64
#  7   avg_heralds_team    84830 non-null  float64
#  8   avg_towers_team     84830 non-null  float64
#  9   avg_dragons_vs_opp  84830 non-null  float64
#  10  avg_barons_vs_opp   84830 non-null  float64
#  11  avg_heralds_vs_opp  84830 non-null  float64
#  12  avg_towers_vs_opp   84830 non-null  float64
#  13  wins_vs_opponent    84830 non-null  int64
# dtypes: bool(1), float64(12), int64(1)
# memory usage: 8.5 MB

# %%
X_train_team.describe()
# Out:
#            goldat10      goldat15        xpat10        xpat15  \
# count  84830.000000  84830.000000  84830.000000  84830.000000
# mean   15517.999402  24504.939024  18335.084838  29338.922900
# std      954.798645   1820.033859    864.702961   1482.786239
# min    11201.000000  16960.000000  12097.000000  19693.000000
# 25%    14893.000000  23281.000000  17827.000000  28414.000000
# 50%    15441.000000  24256.000000  18395.000000  29392.525000
# 75%    16038.000000  25532.000000  18889.000000  30285.000000
# max    24250.000000  39960.000000  25294.000000  37356.000000
#
#        avg_dragons_team  avg_barons_team  avg_heralds_team  avg_towers_team  \
# count      84830.000000     84830.000000      84830.000000     84830.000000
# mean           1.873397         0.691629          0.510084         6.042087
# std            0.599981         0.213876          0.356368         1.461538
# min            0.000000         0.000000          0.000000         0.000000
# 25%            1.526667         0.605469          0.266667         5.442066
# 50%            1.911504         0.714286          0.459459         6.219178
# 75%            2.268794         0.804878          0.726316         6.920490
# max            6.000000         4.000000          2.000000        11.000000
#
#        avg_dragons_vs_opp  avg_barons_vs_opp  avg_heralds_vs_opp  \
# count        84830.000000       84830.000000        84830.000000
# mean             1.662688           0.582331            0.463739
# std              1.126832           0.484049            0.498040
# min              0.000000           0.000000            0.000000
# 25%              1.000000           0.000000            0.000000
# 50%              1.750000           0.600000            0.357143
# 75%              2.428571           0.950000            0.750000
# max              8.000000           6.000000            2.333333
#
#        avg_towers_vs_opp  wins_vs_opponent
# count       84830.000000      84830.000000
# mean            5.064696          3.543157
# std             3.152070          5.049577
# min             0.000000          0.000000
# 25%             2.800000          0.000000
# 50%             5.590909          2.000000
# 75%             7.333333          5.000000
# max            11.000000         49.000000

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_team = pd.DataFrame(
    scaler.fit_transform(X_train_team),
    columns=X_train_team.columns,
    index=X_train_team.index)

X_val_team = pd.DataFrame(
    scaler.fit_transform(X_val_team),
    columns=X_val_team.columns,
    index=X_val_team.index)

X_test_team = pd.DataFrame(
    scaler.fit_transform(X_test_team),
    columns=X_test_team.columns,
    index=X_test_team.index)

# %%
X_train_team.describe()
# Out:
#                side      goldat10      goldat15        xpat10        xpat15  \
# count  84830.000000  8.483000e+04  8.483000e+04  8.483000e+04  8.483000e+04
# mean       0.000000  1.522436e-15  2.251490e-16 -3.248578e-15  4.181338e-16
# std        1.000006  1.000006e+00  1.000006e+00  1.000006e+00  1.000006e+00
# min       -1.000000 -4.521398e+00 -4.145518e+00 -7.214179e+00 -6.505307e+00
# 25%       -1.000000 -6.545915e-01 -6.724854e-01 -5.875866e-01 -6.237773e-01
# 50%        0.000000 -8.064512e-02 -1.367779e-01  6.929029e-02  3.614979e-02
# 75%        1.000000  5.446213e-01  5.643120e-01  6.405881e-01  6.380439e-01
# max        1.000000  9.145438e+00  8.491684e+00  8.047800e+00  5.406797e+00
#
#        avg_dragons_team  avg_barons_team  avg_heralds_team  avg_towers_team  \
# count      8.483000e+04     8.483000e+04      8.483000e+04     8.483000e+04
# mean       4.717407e-16    -7.076111e-16      3.430842e-16    -3.430842e-16
# std        1.000006e+00     1.000006e+00      1.000006e+00     1.000006e+00
# min       -3.122447e+00    -3.233797e+00     -1.431348e+00    -4.134086e+00
# 25%       -5.779055e-01    -4.028516e-01     -6.830538e-01    -4.105431e-01
# 50%        6.351523e-02     1.059358e-01     -1.420571e-01     1.211686e-01
# 75%        6.590198e-01     5.295117e-01      6.067697e-01     6.010169e-01
# max        6.877935e+00     1.546871e+01      4.180861e+00     3.392278e+00
#
#        avg_dragons_vs_opp  avg_barons_vs_opp  avg_heralds_vs_opp  \
# count        8.483000e+04       8.483000e+04        8.483000e+04
# mean        -3.216414e-17       6.968897e-17        2.144276e-17
# std          1.000006e+00       1.000006e+00        1.000006e+00
# min         -1.475551e+00      -1.203050e+00       -9.311338e-01
# 25%         -5.881019e-01      -1.203050e+00       -9.311338e-01
# 50%          7.748484e-02       3.650270e-02       -2.140334e-01
# 75%          6.796824e-01       7.595749e-01        5.747772e-01
# max          5.624041e+00       1.119247e+01        3.753923e+00
#
#        avg_towers_vs_opp  wins_vs_opponent
# count       8.483000e+04      8.483000e+04
# mean       -1.795831e-16      4.020518e-17
# std         1.000006e+00      1.000006e+00
# min        -1.606793e+00     -7.016781e-01
# 25%        -7.184831e-01     -7.016781e-01
# 50%         1.669431e-01     -3.056030e-01
# 75%         7.197335e-01      2.885096e-01
# max         1.882997e+00      9.002161e+00

# %% [markdown]
# # Red neuronal

# %%
print(X_train_team.shape)
print(y_train.unique())
# Out:
# (84830, 14)
# [1 0]

# %%
num_features = len(X_train_team.columns)

network_team = Sequential([
    # 1. Capa de Entrada (Dependerá de cuántas columnas numéricas te queden)
    Input(shape=(num_features,)), 
    
    # 2. Primer Bloque Oculto
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    
    # 3. Segundo Bloque Oculto
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    
    # 4. Tercer Bloque Oculto
    Dense(32, activation='relu'),
    Dropout(0.2),
    
    # 5. Capa de Salida
    Dense(1, activation='sigmoid') 
])

# %%
network_team.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │           1,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,057 (51.00 KB)
#  Trainable params: 12,673 (49.50 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
network_team.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy', AUC(name='auc')])

# %%
history = network_team.fit(X_train_team, 
                      y_train, 
                      epochs=50, 
                      validation_data=(X_val_team, y_val))
# Out:
# Epoch 1/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6956 - auc: 0.7682 - loss: 0.5732 - val_accuracy: 0.6864 - val_auc: 0.7608 - val_loss: 0.5823
# Epoch 2/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6966 - auc: 0.7681 - loss: 0.5738 - val_accuracy: 0.6859 - val_auc: 0.7616 - val_loss: 0.5769
# Epoch 3/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6960 - auc: 0.7682 - loss: 0.5739 - val_accuracy: 0.6860 - val_auc: 0.7611 - val_loss: 0.5775
# Epoch 4/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6955 - auc: 0.7685 - loss: 0.5731 - val_accuracy: 0.6839 - val_auc: 0.7613 - val_loss: 0.5773
# Epoch 5/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6951 - auc: 0.7679 - loss: 0.5736 - val_accuracy: 0.6869 - val_auc: 0.7621 - val_loss: 0.5777
# Epoch 6/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6957 - auc: 0.7687 - loss: 0.5730 - val_accuracy: 0.6855 - val_auc: 0.7606 - val_loss: 0.5781
# Epoch 7/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6951 - auc: 0.7683 - loss: 0.5734 - val_accuracy: 0.6874 - val_auc: 0.7620 - val_loss: 0.5766
# Epoch 8/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6976 - auc: 0.7697 - loss: 0.5722 - val_accuracy: 0.6880 - val_auc: 0.7630 - val_loss: 0.5755
# Epoch 9/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6964 - auc: 0.7697 - loss: 0.5719 - val_accuracy: 0.6857 - val_auc: 0.7613 - val_loss: 0.5771
# Epoch 10/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6961 - auc: 0.7698 - loss: 0.5717 - val_accuracy: 0.6875 - val_auc: 0.7628 - val_loss: 0.5765
# Epoch 11/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6959 - auc: 0.7695 - loss: 0.5718 - val_accuracy: 0.6864 - val_auc: 0.7623 - val_loss: 0.5773
# Epoch 12/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6967 - auc: 0.7701 - loss: 0.5717 - val_accuracy: 0.6855 - val_auc: 0.7613 - val_loss: 0.5770
# Epoch 13/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6962 - auc: 0.7699 - loss: 0.5718 - val_accuracy: 0.6863 - val_auc: 0.7617 - val_loss: 0.5771
# Epoch 14/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6951 - auc: 0.7702 - loss: 0.5711 - val_accuracy: 0.6861 - val_auc: 0.7618 - val_loss: 0.5782
# Epoch 15/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6973 - auc: 0.7713 - loss: 0.5702 - val_accuracy: 0.6854 - val_auc: 0.7621 - val_loss: 0.5772
# Epoch 16/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6969 - auc: 0.7701 - loss: 0.5714 - val_accuracy: 0.6855 - val_auc: 0.7614 - val_loss: 0.5771
# Epoch 17/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6969 - auc: 0.7706 - loss: 0.5709 - val_accuracy: 0.6871 - val_auc: 0.7629 - val_loss: 0.5763
# Epoch 18/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6968 - auc: 0.7711 - loss: 0.5703 - val_accuracy: 0.6888 - val_auc: 0.7626 - val_loss: 0.5759
# Epoch 19/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6964 - auc: 0.7711 - loss: 0.5700 - val_accuracy: 0.6862 - val_auc: 0.7632 - val_loss: 0.5761
# Epoch 20/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6968 - auc: 0.7712 - loss: 0.5705 - val_accuracy: 0.6859 - val_auc: 0.7615 - val_loss: 0.5777
# Epoch 21/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6969 - auc: 0.7706 - loss: 0.5706 - val_accuracy: 0.6867 - val_auc: 0.7627 - val_loss: 0.5764
# Epoch 22/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6965 - auc: 0.7713 - loss: 0.5700 - val_accuracy: 0.6862 - val_auc: 0.7620 - val_loss: 0.5761
# Epoch 23/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6958 - auc: 0.7714 - loss: 0.5696 - val_accuracy: 0.6861 - val_auc: 0.7620 - val_loss: 0.5784
# Epoch 24/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6970 - auc: 0.7717 - loss: 0.5697 - val_accuracy: 0.6850 - val_auc: 0.7622 - val_loss: 0.5769
# Epoch 25/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6978 - auc: 0.7728 - loss: 0.5682 - val_accuracy: 0.6870 - val_auc: 0.7623 - val_loss: 0.5768
# Epoch 26/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6963 - auc: 0.7719 - loss: 0.5692 - val_accuracy: 0.6857 - val_auc: 0.7620 - val_loss: 0.5764
# Epoch 27/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6966 - auc: 0.7716 - loss: 0.5693 - val_accuracy: 0.6874 - val_auc: 0.7623 - val_loss: 0.5763
# Epoch 28/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6967 - auc: 0.7723 - loss: 0.5692 - val_accuracy: 0.6857 - val_auc: 0.7623 - val_loss: 0.5762
# Epoch 29/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6971 - auc: 0.7719 - loss: 0.5697 - val_accuracy: 0.6882 - val_auc: 0.7626 - val_loss: 0.5758
# Epoch 30/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6986 - auc: 0.7721 - loss: 0.5693 - val_accuracy: 0.6872 - val_auc: 0.7614 - val_loss: 0.5775
# Epoch 31/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6975 - auc: 0.7723 - loss: 0.5693 - val_accuracy: 0.6887 - val_auc: 0.7629 - val_loss: 0.5758
# Epoch 32/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6968 - auc: 0.7720 - loss: 0.5692 - val_accuracy: 0.6870 - val_auc: 0.7626 - val_loss: 0.5767
# Epoch 33/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6970 - auc: 0.7720 - loss: 0.5691 - val_accuracy: 0.6857 - val_auc: 0.7618 - val_loss: 0.5767
# Epoch 34/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6977 - auc: 0.7720 - loss: 0.5691 - val_accuracy: 0.6877 - val_auc: 0.7631 - val_loss: 0.5759
# Epoch 35/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6976 - auc: 0.7717 - loss: 0.5694 - val_accuracy: 0.6869 - val_auc: 0.7624 - val_loss: 0.5762
# Epoch 36/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6979 - auc: 0.7722 - loss: 0.5694 - val_accuracy: 0.6863 - val_auc: 0.7616 - val_loss: 0.5778
# Epoch 37/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6966 - auc: 0.7722 - loss: 0.5688 - val_accuracy: 0.6871 - val_auc: 0.7621 - val_loss: 0.5769
# Epoch 38/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6969 - auc: 0.7727 - loss: 0.5685 - val_accuracy: 0.6854 - val_auc: 0.7617 - val_loss: 0.5779
# Epoch 39/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6974 - auc: 0.7724 - loss: 0.5685 - val_accuracy: 0.6850 - val_auc: 0.7621 - val_loss: 0.5782
# Epoch 40/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6981 - auc: 0.7731 - loss: 0.5684 - val_accuracy: 0.6850 - val_auc: 0.7608 - val_loss: 0.5787
# Epoch 41/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6976 - auc: 0.7730 - loss: 0.5684 - val_accuracy: 0.6875 - val_auc: 0.7628 - val_loss: 0.5756
# Epoch 42/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6971 - auc: 0.7730 - loss: 0.5681 - val_accuracy: 0.6850 - val_auc: 0.7613 - val_loss: 0.5766
# Epoch 43/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6997 - auc: 0.7735 - loss: 0.5680 - val_accuracy: 0.6862 - val_auc: 0.7618 - val_loss: 0.5768
# Epoch 44/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7001 - auc: 0.7740 - loss: 0.5676 - val_accuracy: 0.6847 - val_auc: 0.7604 - val_loss: 0.5791
# Epoch 45/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6986 - auc: 0.7732 - loss: 0.5679 - val_accuracy: 0.6865 - val_auc: 0.7611 - val_loss: 0.5787
# Epoch 46/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6966 - auc: 0.7727 - loss: 0.5681 - val_accuracy: 0.6868 - val_auc: 0.7613 - val_loss: 0.5771
# Epoch 47/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6983 - auc: 0.7728 - loss: 0.5683 - val_accuracy: 0.6866 - val_auc: 0.7613 - val_loss: 0.5779
# Epoch 48/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6988 - auc: 0.7736 - loss: 0.5676 - val_accuracy: 0.6864 - val_auc: 0.7613 - val_loss: 0.5776
# Epoch 49/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6986 - auc: 0.7736 - loss: 0.5679 - val_accuracy: 0.6865 - val_auc: 0.7619 - val_loss: 0.5775
# Epoch 50/50
# 2651/2651 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6981 - auc: 0.7736 - loss: 0.5678 - val_accuracy: 0.6871 - val_auc: 0.7620 - val_loss: 0.5780

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(10, 7))
plt.grid(True)
plt.gca().set_ylim(0, 1.2)
plt.xlabel("epochs")
plt.show()

# %%
test_loss, test_acc, test_prec = network_team.evaluate(X_test_team, y_test)
# Out:
# 1656/1656 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6623 - auc: 0.7333 - loss: 0.6073

# %%
print('test_acc:', test_acc)
print('test_prec:', test_prec)
print('test_loss:', test_loss)
# Out:
# test_acc: 0.662306547164917
# test_prec: 0.7333402633666992
# test_loss: 0.6072559356689453

# %%
network_team.save("../Data/Model/Neuronal_net.keras")

# %% [markdown]
# # Verificación modelo

# %%
model = keras.models.load_model("../Data/Model/Neuronal_net.keras")
