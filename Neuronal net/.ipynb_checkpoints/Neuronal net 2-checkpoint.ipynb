# %% [raw]
# pip install tensorflow

# %%
import numpy as np
import pandas as pd
from calc_rates2 import calc_rates
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.metrics import AUC

print('TensorFlow:', tf.__version__)
# Out:
# TensorFlow: 2.21.0

# %%
# Leer todos los archivos
dfs = []
lens = []
#Los primeros años tienen algunas carencias de datos y 2021 es un año con muchos.
for year in range(2014,2027):
    df = pd.read_csv(f"../Data/Procesed data/Re-formulated data/{year}_LoL_esports_match_data_from_OraclesElixir.csv",low_memory=False)
    lens.append(len(df))
    dfs.append(df)
# [2014, 2015, 2016,  2017,  2018,  2019,  2020,  2021,  2022,  2023,  2024,  2025,  2026]
# [1836, 3630, 8428, 11010, 13472, 16250, 19494, 24604, 25058, 22212, 20390, 20082, 12508]
# | -      -    -  [train                     ][val         ] [test       ] -          - |
# print(lens)

complete_set  = pd.concat(dfs, ignore_index=True)
complete_set = calc_rates(complete_set)
columnas_equipo_mudas = ["gameid","team","result","side","goldat10","goldat15","xpat10","xpat15","avg_dragons_team","avg_barons_team","avg_heralds_team","avg_towers_team","avg_dragons_vs_opp","avg_barons_vs_opp","avg_heralds_vs_opp","avg_towers_vs_opp","wins_vs_opponent"]
complete_set = complete_set[columnas_equipo_mudas]

index_train = sum(lens[i] for i in range(3))
index_val = sum(lens[i] for i in range(7))
index_test = sum(lens[i] for i in range(9))
index_final = sum(lens[i] for i in range(11))

print("Train: ",index_val-index_train)
print("Val: ",index_test-index_val)
print("Test: ",index_final-index_test)

train_set = complete_set[index_train:index_val]
val_set = complete_set[index_val:index_test]
test_set = complete_set[index_test:index_final]

train_set.to_csv("../Data/Net/train_data2.csv",index=False)
val_set.to_csv("../Data/Net/val_data2.csv",index=False)
test_set.to_csv("../Data/Net/test_data2.csv",index=False)
# Out:
# Train:  60226
# Val:  49662
# Test:  42602

# %% [raw]
# train_set = pd.read_csv("../Data/Net/train_data2.csv")
# val_set = pd.read_csv("../Data/Net/val_data2.csv")
# test_set = pd.read_csv("../Data/Net/test_data2.csv")

# %% [markdown]
# # Poda de columnas y datos

# %%
def remove_labels(df, label_name):
    X = df.drop(label_name, axis=1)
    y = df[label_name].copy()
    return (X, y)

# %%
X_train, y_train = remove_labels(train_set, 'result')
X_val, y_val = remove_labels(val_set, 'result')
X_test, y_test = remove_labels(test_set, 'result')

# %%
assert(len(X_train) == len(y_train))
print("Entrenamiento:",len(X_train))

assert(len(X_val) == len(y_val))
print("Val:",len(X_val))

assert(len(X_test) == len(y_test))
print("Prueba:",len(X_test))
# Out:
# Entrenamiento: 60226
# Val: 49662
# Prueba: 42602

# %%
columnas_equipo_mudas = ["side","goldat10","goldat15","xpat10","xpat15","avg_dragons_team","avg_barons_team","avg_heralds_team","avg_towers_team","avg_dragons_vs_opp","avg_barons_vs_opp","avg_heralds_vs_opp","avg_towers_vs_opp","wins_vs_opponent"]

# %%
X_train_team = X_train[columnas_equipo_mudas]
X_val_team = X_val[columnas_equipo_mudas]
X_test_team = X_test[columnas_equipo_mudas]

# %%
print("-"*35)
print(X_train_team.isnull().sum())
print("-"*35)
print(X_val_team.isnull().sum())
print("-"*35)
print(X_test_team.isnull().sum())
# Out:
# -----------------------------------
# side                  0
# goldat10              0
# goldat15              0
# xpat10                0
# xpat15                0
# avg_dragons_team      0
# avg_barons_team       0
# avg_heralds_team      0
# avg_towers_team       0
# avg_dragons_vs_opp    0
# avg_barons_vs_opp     0
# avg_heralds_vs_opp    0
# avg_towers_vs_opp     0
# wins_vs_opponent      0
# dtype: int64
# -----------------------------------
# side                  0
# goldat10              0
# goldat15              0
# xpat10                0
# xpat15                0
# avg_dragons_team      0
# avg_barons_team       0
# avg_heralds_team      0
# avg_towers_team       0
# avg_dragons_vs_opp    0
# avg_barons_vs_opp     0
# avg_heralds_vs_opp    0
# avg_towers_vs_opp     0
# wins_vs_opponent      0
# dtype: int64
# -----------------------------------
# side                  0
# goldat10              0
# goldat15              0
# xpat10                0
# xpat15                0
# avg_dragons_team      0
# avg_barons_team       0
# avg_heralds_team      0
# avg_towers_team       0
# avg_dragons_vs_opp    0
# avg_barons_vs_opp     0
# avg_heralds_vs_opp    0
# avg_towers_vs_opp     0
# wins_vs_opponent      0
# dtype: int64

# %%
X_train_team.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60226 entries, 13894 to 74119
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   side                60226 non-null  bool
#  1   goldat10            60226 non-null  float64
#  2   goldat15            60226 non-null  float64
#  3   xpat10              60226 non-null  float64
#  4   xpat15              60226 non-null  float64
#  5   avg_dragons_team    60226 non-null  float64
#  6   avg_barons_team     60226 non-null  float64
#  7   avg_heralds_team    60226 non-null  float64
#  8   avg_towers_team     60226 non-null  float64
#  9   avg_dragons_vs_opp  60226 non-null  float64
#  10  avg_barons_vs_opp   60226 non-null  float64
#  11  avg_heralds_vs_opp  60226 non-null  float64
#  12  avg_towers_vs_opp   60226 non-null  float64
#  13  wins_vs_opponent    60226 non-null  int64
# dtypes: bool(1), float64(12), int64(1)
# memory usage: 6.0 MB

# %%
X_train_team.describe()
# Out:
#            goldat10      goldat15        xpat10        xpat15  \
# count  60226.000000  60226.000000  60226.000000  60226.000000
# mean   15419.976236  24328.384456  18332.834974  29291.307487
# std      925.052333   1771.256555    856.632624   1479.436541
# min    11201.000000  16960.000000  12097.000000  19693.000000
# 25%    14822.000000  23155.000000  17835.000000  28377.000000
# 50%    15336.000000  24176.000000  18386.000000  29326.000000
# 75%    15900.039604  25296.000000  18868.000000  30218.338235
# max    23641.000000  35469.000000  25294.000000  37356.000000
#
#        avg_dragons_team  avg_barons_team  avg_heralds_team  avg_towers_team  \
# count      60226.000000     60226.000000      60226.000000     60226.000000
# mean           1.757716         0.702746          0.416222         6.096267
# std            0.604428         0.218410          0.305321         1.477563
# min            0.000000         0.000000          0.000000         0.000000
# 25%            1.419355         0.615385          0.223140         5.493988
# 50%            1.765014         0.726316          0.397985         6.267857
# 75%            2.125000         0.820513          0.552632         7.000000
# max            6.000000         4.000000          2.000000        11.000000
#
#        avg_dragons_vs_opp  avg_barons_vs_opp  avg_heralds_vs_opp  \
# count        60226.000000       60226.000000        60226.000000
# mean             1.571948           0.591409            0.383083
# std              1.111886           0.492772            0.438035
# min              0.000000           0.000000            0.000000
# 25%              0.750000           0.000000            0.000000
# 50%              1.625000           0.600000            0.294118
# 75%              2.300000           1.000000            0.600000
# max              8.000000           6.000000            2.333333
#
#        avg_towers_vs_opp  wins_vs_opponent
# count       60226.000000      60226.000000
# mean            5.097869          3.394863
# std             3.187606          4.776862
# min             0.000000          0.000000
# 25%             2.750000          0.000000
# 50%             5.632456          2.000000
# 75%             7.434783          5.000000
# max            11.000000         48.000000

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_team = pd.DataFrame(
    scaler.fit_transform(X_train_team),
    columns=X_train_team.columns,
    index=X_train_team.index)

X_val_team = pd.DataFrame(
    scaler.transform(X_val_team),
    columns=X_val_team.columns,
    index=X_val_team.index)

X_test_team = pd.DataFrame(
    scaler.transform(X_test_team),
    columns=X_test_team.columns,
    index=X_test_team.index)

# %%
X_train_team.describe()
# Out:
#                side      goldat10      goldat15        xpat10        xpat15  \
# count  60226.000000  6.022600e+04  6.022600e+04  6.022600e+04  6.022600e+04
# mean       0.000000  6.946627e-16  1.094849e-15  2.083988e-15 -9.362845e-16
# std        1.000008  1.000008e+00  1.000008e+00  1.000008e+00  1.000008e+00
# min       -1.000000 -4.560835e+00 -4.160010e+00 -7.279535e+00 -6.487867e+00
# 25%       -1.000000 -6.464296e-01 -6.624643e-01 -5.811582e-01 -6.180157e-01
# 50%        0.000000 -9.078074e-02 -8.603255e-02  6.206332e-02  2.345001e-02
# 75%        1.000000  5.189624e-01  5.462922e-01  6.247363e-01  6.266159e-01
# max        1.000000  8.887164e+00  6.289720e+00  8.126264e+00  5.451237e+00
#
#        avg_dragons_team  avg_barons_team  avg_heralds_team  avg_towers_team  \
# count      6.022600e+04     6.022600e+04      6.022600e+04     6.022600e+04
# mean       6.040545e-17    -1.887670e-16     -9.060818e-17     1.321369e-16
# std        1.000008e+00     1.000008e+00      1.000008e+00     1.000008e+00
# min       -2.908090e+00    -3.217580e+00     -1.363239e+00    -4.125926e+00
# 25%       -5.598093e-01    -3.999909e-01     -6.323931e-01    -4.076200e-01
# 50%        1.207307e-02     1.079165e-01     -5.973120e-02     1.161313e-01
# 75%        6.076599e-01     5.392053e-01      4.467798e-01     6.116422e-01
# max        7.018733e+00     1.509675e+01      5.187305e+00     3.318824e+00
#
#        avg_dragons_vs_opp  avg_barons_vs_opp  avg_heralds_vs_opp  \
# count        6.022600e+04       6.022600e+04        6.022600e+04
# mean        -1.208109e-16      -6.040545e-17        6.040545e-17
# std          1.000008e+00       1.000008e+00        1.000008e+00
# min         -1.413780e+00      -1.200176e+00       -8.745559e-01
# 25%         -7.392441e-01      -1.200176e+00       -8.745559e-01
# 50%          4.771398e-02       1.743508e-02       -2.031031e-01
# 75%          6.547959e-01       8.291757e-01        4.952078e-01
# max          5.781266e+00       1.097593e+01        4.452303e+00
#
#        avg_towers_vs_opp  wins_vs_opponent
# count       6.022600e+04      6.022600e+04
# mean       -9.438352e-17     -6.606846e-17
# std         1.000008e+00      1.000008e+00
# min        -1.599292e+00     -7.106948e-01
# 25%        -7.365681e-01     -7.106948e-01
# 50%         1.677093e-01     -2.920064e-01
# 75%         7.331310e-01      3.360262e-01
# max         1.851603e+00      9.337826e+00

# %% [markdown]
# # Red neuronal

# %%
print(X_train_team.shape)
print(y_train.unique())
# Out:
# (60226, 14)
# [1 0]

# %%
num_features = len(X_train_team.columns)

network_team = Sequential([
    # 1. Capa de Entrada (Dependerá de cuántas columnas numéricas te queden)
    Input(shape=(num_features,)), 
    
    # 2. Primer Bloque Oculto
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    
    # 3. Segundo Bloque Oculto
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    
    # 4. Tercer Bloque Oculto
    Dense(32, activation='relu'),
    Dropout(0.2),
    
    # 5. Capa de Salida
    Dense(1, activation='sigmoid') 
])

# %%
network_team.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │           1,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,057 (51.00 KB)
#  Trainable params: 12,673 (49.50 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
network_team.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy', AUC(name='auc')])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = network_team.fit(X_train_team, 
                      y_train, 
                      epochs=50, 
                      validation_data=(X_val_team, y_val))
# Out:
# Epoch 1/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6730 - auc: 0.7392 - loss: 0.6015 - val_accuracy: 0.6842 - val_auc: 0.7693 - val_loss: 0.5830
# Epoch 2/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6869 - auc: 0.7558 - loss: 0.5856 - val_accuracy: 0.6860 - val_auc: 0.7700 - val_loss: 0.5763
# Epoch 3/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6892 - auc: 0.7594 - loss: 0.5825 - val_accuracy: 0.6873 - val_auc: 0.7704 - val_loss: 0.5838
# Epoch 4/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6907 - auc: 0.7621 - loss: 0.5797 - val_accuracy: 0.6912 - val_auc: 0.7705 - val_loss: 0.5756
# Epoch 5/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6913 - auc: 0.7624 - loss: 0.5791 - val_accuracy: 0.6846 - val_auc: 0.7706 - val_loss: 0.5827
# Epoch 6/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6901 - auc: 0.7627 - loss: 0.5791 - val_accuracy: 0.6864 - val_auc: 0.7715 - val_loss: 0.5833
# Epoch 7/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6910 - auc: 0.7641 - loss: 0.5782 - val_accuracy: 0.6921 - val_auc: 0.7717 - val_loss: 0.5733
# Epoch 8/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6930 - auc: 0.7635 - loss: 0.5780 - val_accuracy: 0.6924 - val_auc: 0.7726 - val_loss: 0.5757
# Epoch 9/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6930 - auc: 0.7653 - loss: 0.5772 - val_accuracy: 0.6858 - val_auc: 0.7717 - val_loss: 0.5741
# Epoch 10/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6930 - auc: 0.7645 - loss: 0.5775 - val_accuracy: 0.6863 - val_auc: 0.7706 - val_loss: 0.5822
# Epoch 11/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6933 - auc: 0.7651 - loss: 0.5767 - val_accuracy: 0.6916 - val_auc: 0.7711 - val_loss: 0.5798
# Epoch 12/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6925 - auc: 0.7653 - loss: 0.5766 - val_accuracy: 0.6943 - val_auc: 0.7715 - val_loss: 0.5745
# Epoch 13/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6937 - auc: 0.7668 - loss: 0.5751 - val_accuracy: 0.6894 - val_auc: 0.7720 - val_loss: 0.5803
# Epoch 14/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6922 - auc: 0.7665 - loss: 0.5749 - val_accuracy: 0.6949 - val_auc: 0.7712 - val_loss: 0.5693
# Epoch 15/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6945 - auc: 0.7670 - loss: 0.5750 - val_accuracy: 0.6921 - val_auc: 0.7714 - val_loss: 0.5729
# Epoch 16/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6942 - auc: 0.7665 - loss: 0.5753 - val_accuracy: 0.6909 - val_auc: 0.7716 - val_loss: 0.5816
# Epoch 17/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6926 - auc: 0.7667 - loss: 0.5749 - val_accuracy: 0.6885 - val_auc: 0.7714 - val_loss: 0.5757
# Epoch 18/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6950 - auc: 0.7677 - loss: 0.5745 - val_accuracy: 0.6821 - val_auc: 0.7708 - val_loss: 0.5900
# Epoch 19/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6936 - auc: 0.7684 - loss: 0.5725 - val_accuracy: 0.6877 - val_auc: 0.7713 - val_loss: 0.5876
# Epoch 20/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6939 - auc: 0.7680 - loss: 0.5738 - val_accuracy: 0.6944 - val_auc: 0.7719 - val_loss: 0.5701
# Epoch 21/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6936 - auc: 0.7679 - loss: 0.5737 - val_accuracy: 0.6880 - val_auc: 0.7719 - val_loss: 0.5793
# Epoch 22/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6947 - auc: 0.7680 - loss: 0.5736 - val_accuracy: 0.6904 - val_auc: 0.7717 - val_loss: 0.5789
# Epoch 23/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6931 - auc: 0.7685 - loss: 0.5730 - val_accuracy: 0.6861 - val_auc: 0.7714 - val_loss: 0.5792
# Epoch 24/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6938 - auc: 0.7694 - loss: 0.5722 - val_accuracy: 0.6924 - val_auc: 0.7715 - val_loss: 0.5782
# Epoch 25/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6958 - auc: 0.7690 - loss: 0.5727 - val_accuracy: 0.6904 - val_auc: 0.7715 - val_loss: 0.5783
# Epoch 26/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6956 - auc: 0.7699 - loss: 0.5719 - val_accuracy: 0.6906 - val_auc: 0.7716 - val_loss: 0.5773
# Epoch 27/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6957 - auc: 0.7699 - loss: 0.5712 - val_accuracy: 0.6870 - val_auc: 0.7724 - val_loss: 0.5829
# Epoch 28/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6963 - auc: 0.7694 - loss: 0.5722 - val_accuracy: 0.6903 - val_auc: 0.7714 - val_loss: 0.5811
# Epoch 29/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6941 - auc: 0.7695 - loss: 0.5716 - val_accuracy: 0.6932 - val_auc: 0.7716 - val_loss: 0.5768
# Epoch 30/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6949 - auc: 0.7694 - loss: 0.5723 - val_accuracy: 0.6880 - val_auc: 0.7714 - val_loss: 0.5772
# Epoch 31/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6957 - auc: 0.7701 - loss: 0.5718 - val_accuracy: 0.6894 - val_auc: 0.7717 - val_loss: 0.5751
# Epoch 32/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6951 - auc: 0.7700 - loss: 0.5710 - val_accuracy: 0.6897 - val_auc: 0.7712 - val_loss: 0.5808
# Epoch 33/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6954 - auc: 0.7700 - loss: 0.5711 - val_accuracy: 0.6897 - val_auc: 0.7706 - val_loss: 0.5810
# Epoch 34/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6944 - auc: 0.7704 - loss: 0.5711 - val_accuracy: 0.6917 - val_auc: 0.7717 - val_loss: 0.5766
# Epoch 35/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6952 - auc: 0.7703 - loss: 0.5710 - val_accuracy: 0.6916 - val_auc: 0.7708 - val_loss: 0.5836
# Epoch 36/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6959 - auc: 0.7704 - loss: 0.5712 - val_accuracy: 0.6892 - val_auc: 0.7701 - val_loss: 0.5831
# Epoch 37/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6948 - auc: 0.7710 - loss: 0.5706 - val_accuracy: 0.6860 - val_auc: 0.7711 - val_loss: 0.5843
# Epoch 38/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6958 - auc: 0.7708 - loss: 0.5709 - val_accuracy: 0.6896 - val_auc: 0.7712 - val_loss: 0.5799
# Epoch 39/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6999 - auc: 0.7723 - loss: 0.5695 - val_accuracy: 0.6906 - val_auc: 0.7704 - val_loss: 0.5771
# Epoch 40/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6970 - auc: 0.7717 - loss: 0.5701 - val_accuracy: 0.6900 - val_auc: 0.7702 - val_loss: 0.5746
# Epoch 41/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6962 - auc: 0.7716 - loss: 0.5700 - val_accuracy: 0.6878 - val_auc: 0.7698 - val_loss: 0.5741
# Epoch 42/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6963 - auc: 0.7717 - loss: 0.5699 - val_accuracy: 0.6909 - val_auc: 0.7706 - val_loss: 0.5790
# Epoch 43/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6951 - auc: 0.7717 - loss: 0.5698 - val_accuracy: 0.6893 - val_auc: 0.7707 - val_loss: 0.5777
# Epoch 44/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6959 - auc: 0.7716 - loss: 0.5699 - val_accuracy: 0.6915 - val_auc: 0.7713 - val_loss: 0.5801
# Epoch 45/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6959 - auc: 0.7718 - loss: 0.5697 - val_accuracy: 0.6889 - val_auc: 0.7697 - val_loss: 0.5781
# Epoch 46/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6964 - auc: 0.7718 - loss: 0.5698 - val_accuracy: 0.6921 - val_auc: 0.7712 - val_loss: 0.5759
# Epoch 47/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6968 - auc: 0.7720 - loss: 0.5695 - val_accuracy: 0.6847 - val_auc: 0.7706 - val_loss: 0.5827
# Epoch 48/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6972 - auc: 0.7727 - loss: 0.5688 - val_accuracy: 0.6907 - val_auc: 0.7708 - val_loss: 0.5727
# Epoch 49/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6965 - auc: 0.7726 - loss: 0.5688 - val_accuracy: 0.6914 - val_auc: 0.7698 - val_loss: 0.5758
# Epoch 50/50
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6948 - auc: 0.7723 - loss: 0.5690 - val_accuracy: 0.6888 - val_auc: 0.7712 - val_loss: 0.5772

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(10, 7))
plt.grid(True)
plt.gca().set_ylim(0, 1.2)
plt.xlabel("epochs")
plt.show()

# %%
test_loss, test_acc, test_prec = network_team.evaluate(X_test_team, y_test)
# Out:
# 1332/1332 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6596 - auc: 0.7566 - loss: 0.6035

# %%
print('test_acc:', test_acc)
print('test_prec:', test_prec)
print('test_loss:', test_loss)
# Out:
# test_acc: 0.6596169471740723
# test_prec: 0.7565836906433105
# test_loss: 0.6034759283065796

# %%
network_team.save("../Data/Model/Neuronal_net.keras")

# %% [markdown]
# # Verificación modelo

# %%
model = keras.models.load_model("../Data/Model/Neuronal_net.keras")
