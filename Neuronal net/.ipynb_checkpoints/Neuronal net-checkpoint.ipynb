# %% [markdown]
# # Imports

# %%
"""pip install tensorflow"""
# Out:
# 'pip install tensorflow'

# %%
import numpy as np
import pandas as pd
from calc_rates import calc_rates
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.metrics import AUC

print('TensorFlow:', tf.__version__)
# Out:
# TensorFlow: 2.21.0

# %% [markdown]
# Immportar todos los datos. Para tener medias bien hechas en el uso de campeones y winrate luego se desecharán los primeros archivos que además contienen aujeros importantes de datos.

# %% [raw]
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# # Leer todos los archivos
# dfs = []
#
# #Los primeros años tienen algunas carencias de datos y 2021 es un año con muchos.
# for year in range(2018,2022):
#     df = pd.read_csv(f"../Data/Procesed data/Re-formulated data/{year}_LoL_esports_match_data_from_OraclesElixir.csv",low_memory=False)
#     dfs.append(df)
#
# # Unir train
# train_set = pd.concat(dfs, ignore_index=True)
#
# dfs = []
# for year in range(2022,2024):
#     df = pd.read_csv(f"../Data/Procesed data/Re-formulated data/{year}_LoL_esports_match_data_from_OraclesElixir.csv",low_memory=False)
#     dfs.append(df)
#
# # Unir val
# val_set = pd.concat(dfs, ignore_index=True)
#
# dfs = []
# for year in range(2024,2027):
#     df = pd.read_csv(f"../Data/Procesed data/Re-formulated data/{year}_LoL_esports_match_data_from_OraclesElixir.csv",low_memory=False)
#     dfs.append(df)
#
# # Unir test
# test_set  = pd.concat(dfs, ignore_index=True)
#
#
# train_set = calc_rates(train_set)
# val_set = calc_rates(val_set)
# test_set = calc_rates(test_set)
#
# train_set.to_csv("../Data/Net/train_data.csv",index=False)
# val_set.to_csv("../Data/Net/val_data.csv",index=False)
# test_set.to_csv("../Data/Net/test_data.csv",index=False)

# %% [markdown]
# Tras haber ejecutado una vez el anterior, los datos se pueden cargar rápidamente con el siguiente codigo

# %%
train_set = pd.read_csv("../Data/Net/train_data.csv")
val_set = pd.read_csv("../Data/Net/val_data.csv")
test_set = pd.read_csv("../Data/Net/test_data.csv")

# %% [markdown]
# # Separación de features con labels

# %% [markdown]
# La label es la columna result. Además hay que deshacerse de unas cuantas columnas. Como los nombres de los jugadores y equipos que se han usado para clasificar las últimas métricas.

# %%
def remove_labels(df, label_name):
    X = df.drop(label_name, axis=1)
    y = df[label_name].copy()
    return (X, y)

# %%
train_set.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 73820 entries, 0 to 73819
# Data columns (total 98 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gameid                      73820 non-null  str
#  1   side                        73820 non-null  bool
#  2   p1_name                     73604 non-null  str
#  3   p1_champion                 73820 non-null  str
#  4   p1_champion_id              73820 non-null  int64
#  5   p1_champion_last30_winrate  73820 non-null  float64
#  6   p1_kills                    73820 non-null  int64
#  7   p1_deaths                   73820 non-null  int64
#  8   p1_pentakill                73820 non-null  float64
#  9   p1_assist                   73820 non-null  int64
#  10  p1_dpm                      73820 non-null  float64
#  11  p1_cspm                     73518 non-null  float64
#  12  p1_vspm                     73820 non-null  float64
#  13  p1_firstblood               73578 non-null  float64
#  14  p1_firstbloodassist         73820 non-null  float64
#  15  p1_goldat10                 73820 non-null  float64
#  16  p1_goldat15                 73820 non-null  float64
#  17  p1_xpat10                   73820 non-null  float64
#  18  p1_xpat15                   73820 non-null  float64
#  19  p2_name                     73594 non-null  str
#  20  p2_champion                 73820 non-null  str
#  21  p2_champion_id              73820 non-null  int64
#  22  p2_champion_last30_winrate  73820 non-null  float64
#  23  p2_kills                    73820 non-null  int64
#  24  p2_deaths                   73820 non-null  int64
#  25  p2_pentakill                73820 non-null  float64
#  26  p2_assist                   73820 non-null  int64
#  27  p2_dpm                      73820 non-null  float64
#  28  p2_cspm                     73518 non-null  float64
#  29  p2_vspm                     73820 non-null  float64
#  30  p2_firstblood               73578 non-null  float64
#  31  p2_firstbloodassist         73820 non-null  float64
#  32  p2_goldat10                 73820 non-null  float64
#  33  p2_goldat15                 73820 non-null  float64
#  34  p2_xpat10                   73820 non-null  float64
#  35  p2_xpat15                   73820 non-null  float64
#  36  p3_name                     73614 non-null  str
#  37  p3_champion                 73820 non-null  str
#  38  p3_champion_id              73820 non-null  int64
#  39  p3_champion_last30_winrate  73820 non-null  float64
#  40  p3_kills                    73820 non-null  int64
#  41  p3_deaths                   73820 non-null  int64
#  42  p3_pentakill                73820 non-null  float64
#  43  p3_assist                   73820 non-null  int64
#  44  p3_dpm                      73820 non-null  float64
#  45  p3_cspm                     73518 non-null  float64
#  46  p3_vspm                     73820 non-null  float64
#  47  p3_firstblood               73578 non-null  float64
#  48  p3_firstbloodassist         73820 non-null  float64
#  49  p3_goldat10                 73820 non-null  float64
#  50  p3_goldat15                 73820 non-null  float64
#  51  p3_xpat10                   73820 non-null  float64
#  52  p3_xpat15                   73820 non-null  float64
#  53  p4_name                     73613 non-null  str
#  54  p4_champion                 73820 non-null  str
#  55  p4_champion_id              73820 non-null  int64
#  56  p4_champion_last30_winrate  73820 non-null  float64
#  57  p4_kills                    73820 non-null  int64
#  58  p4_deaths                   73820 non-null  int64
#  59  p4_pentakill                73820 non-null  float64
#  60  p4_assist                   73820 non-null  int64
#  61  p4_dpm                      73820 non-null  float64
#  62  p4_cspm                     73518 non-null  float64
#  63  p4_vspm                     73820 non-null  float64
#  64  p4_firstblood               73578 non-null  float64
#  65  p4_firstbloodassist         73820 non-null  float64
#  66  p4_goldat10                 73820 non-null  float64
#  67  p4_goldat15                 73820 non-null  float64
#  68  p4_xpat10                   73820 non-null  float64
#  69  p4_xpat15                   73820 non-null  float64
#  70  p5_name                     73621 non-null  str
#  71  p5_champion                 73820 non-null  str
#  72  p5_champion_id              73820 non-null  int64
#  73  p5_champion_last30_winrate  73820 non-null  float64
#  74  p5_kills                    73820 non-null  int64
#  75  p5_deaths                   73820 non-null  int64
#  76  p5_pentakill                73820 non-null  float64
#  77  p5_assist                   73820 non-null  int64
#  78  p5_dpm                      73820 non-null  float64
#  79  p5_cspm                     73518 non-null  float64
#  80  p5_vspm                     73820 non-null  float64
#  81  p5_firstblood               73578 non-null  float64
#  82  p5_firstbloodassist         73820 non-null  float64
#  83  p5_goldat10                 73820 non-null  float64
#  84  p5_goldat15                 73820 non-null  float64
#  85  p5_xpat10                   73820 non-null  float64
#  86  p5_xpat15                   73820 non-null  float64
#  87  team                        73799 non-null  str
#  88  dragons                     73820 non-null  float64
#  89  barons                      73820 non-null  float64
#  90  heralds                     73820 non-null  float64
#  91  towers                      73820 non-null  float64
#  92  result                      73820 non-null  int64
#  93  goldat10                    73820 non-null  float64
#  94  goldat15                    73820 non-null  float64
#  95  xpat10                      73820 non-null  float64
#  96  xpat15                      73820 non-null  float64
#  97  wins_vs_opponent            73820 non-null  int64
# dtypes: bool(1), float64(63), int64(22), str(12)
# memory usage: 61.1 MB

# %%
for i in range(1,6):
    train_set = train_set.drop(f"p{i}_name",axis=1)
    train_set = train_set.drop(f"p{i}_champion",axis=1)
    
train_set = train_set.drop("gameid",axis=1)
train_set = train_set.drop("team",axis=1)

for i in range(1,6):
    val_set = val_set.drop(f"p{i}_name",axis=1)
    val_set = val_set.drop(f"p{i}_champion",axis=1)

val_set = val_set.drop("gameid",axis=1)
val_set = val_set.drop("team",axis=1)

for i in range(1,6):
    test_set = test_set.drop(f"p{i}_name",axis=1)
    test_set = test_set.drop(f"p{i}_champion",axis=1)

test_set = test_set.drop("gameid",axis=1)
test_set = test_set.drop("team",axis=1)

champion_columns = [f"p{i}_champion_id"for i in range(1,6)]
train_set[champion_columns] = train_set[champion_columns].astype("category")
val_set[champion_columns] = train_set[champion_columns].astype("category")
test_set[champion_columns] = train_set[champion_columns].astype("category")

# %%
train_set.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 73820 entries, 0 to 73819
# Data columns (total 86 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   side                        73820 non-null  bool
#  1   p1_champion_id              73820 non-null  category
#  2   p1_champion_last30_winrate  73820 non-null  float64
#  3   p1_kills                    73820 non-null  int64
#  4   p1_deaths                   73820 non-null  int64
#  5   p1_pentakill                73820 non-null  float64
#  6   p1_assist                   73820 non-null  int64
#  7   p1_dpm                      73820 non-null  float64
#  8   p1_cspm                     73518 non-null  float64
#  9   p1_vspm                     73820 non-null  float64
#  10  p1_firstblood               73578 non-null  float64
#  11  p1_firstbloodassist         73820 non-null  float64
#  12  p1_goldat10                 73820 non-null  float64
#  13  p1_goldat15                 73820 non-null  float64
#  14  p1_xpat10                   73820 non-null  float64
#  15  p1_xpat15                   73820 non-null  float64
#  16  p2_champion_id              73820 non-null  category
#  17  p2_champion_last30_winrate  73820 non-null  float64
#  18  p2_kills                    73820 non-null  int64
#  19  p2_deaths                   73820 non-null  int64
#  20  p2_pentakill                73820 non-null  float64
#  21  p2_assist                   73820 non-null  int64
#  22  p2_dpm                      73820 non-null  float64
#  23  p2_cspm                     73518 non-null  float64
#  24  p2_vspm                     73820 non-null  float64
#  25  p2_firstblood               73578 non-null  float64
#  26  p2_firstbloodassist         73820 non-null  float64
#  27  p2_goldat10                 73820 non-null  float64
#  28  p2_goldat15                 73820 non-null  float64
#  29  p2_xpat10                   73820 non-null  float64
#  30  p2_xpat15                   73820 non-null  float64
#  31  p3_champion_id              73820 non-null  category
#  32  p3_champion_last30_winrate  73820 non-null  float64
#  33  p3_kills                    73820 non-null  int64
#  34  p3_deaths                   73820 non-null  int64
#  35  p3_pentakill                73820 non-null  float64
#  36  p3_assist                   73820 non-null  int64
#  37  p3_dpm                      73820 non-null  float64
#  38  p3_cspm                     73518 non-null  float64
#  39  p3_vspm                     73820 non-null  float64
#  40  p3_firstblood               73578 non-null  float64
#  41  p3_firstbloodassist         73820 non-null  float64
#  42  p3_goldat10                 73820 non-null  float64
#  43  p3_goldat15                 73820 non-null  float64
#  44  p3_xpat10                   73820 non-null  float64
#  45  p3_xpat15                   73820 non-null  float64
#  46  p4_champion_id              73820 non-null  category
#  47  p4_champion_last30_winrate  73820 non-null  float64
#  48  p4_kills                    73820 non-null  int64
#  49  p4_deaths                   73820 non-null  int64
#  50  p4_pentakill                73820 non-null  float64
#  51  p4_assist                   73820 non-null  int64
#  52  p4_dpm                      73820 non-null  float64
#  53  p4_cspm                     73518 non-null  float64
#  54  p4_vspm                     73820 non-null  float64
#  55  p4_firstblood               73578 non-null  float64
#  56  p4_firstbloodassist         73820 non-null  float64
#  57  p4_goldat10                 73820 non-null  float64
#  58  p4_goldat15                 73820 non-null  float64
#  59  p4_xpat10                   73820 non-null  float64
#  60  p4_xpat15                   73820 non-null  float64
#  61  p5_champion_id              73820 non-null  category
#  62  p5_champion_last30_winrate  73820 non-null  float64
#  63  p5_kills                    73820 non-null  int64
#  64  p5_deaths                   73820 non-null  int64
#  65  p5_pentakill                73820 non-null  float64
#  66  p5_assist                   73820 non-null  int64
#  67  p5_dpm                      73820 non-null  float64
#  68  p5_cspm                     73518 non-null  float64
#  69  p5_vspm                     73820 non-null  float64
#  70  p5_firstblood               73578 non-null  float64
#  71  p5_firstbloodassist         73820 non-null  float64
#  72  p5_goldat10                 73820 non-null  float64
#  73  p5_goldat15                 73820 non-null  float64
#  74  p5_xpat10                   73820 non-null  float64
#  75  p5_xpat15                   73820 non-null  float64
#  76  dragons                     73820 non-null  float64
#  77  barons                      73820 non-null  float64
#  78  heralds                     73820 non-null  float64
#  79  towers                      73820 non-null  float64
#  80  result                      73820 non-null  int64
#  81  goldat10                    73820 non-null  float64
#  82  goldat15                    73820 non-null  float64
#  83  xpat10                      73820 non-null  float64
#  84  xpat15                      73820 non-null  float64
#  85  wins_vs_opponent            73820 non-null  int64
# dtypes: bool(1), category(5), float64(63), int64(17)
# memory usage: 45.7 MB

# %%
X_train, y_train_prep = remove_labels(train_set, 'result')
X_val, y_val_prep = remove_labels(val_set, 'result')
X_test, y_test_prep = remove_labels(test_set, 'result')

# %%
assert(len(X_train) == len(y_train_prep))
print("Entrenamiento:",len(X_train))

assert(len(X_val) == len(y_val_prep))
print("Val:",len(X_val))

assert(len(X_test) == len(y_test_prep))
print("Prueba:",len(X_test))
# Out:
# Entrenamiento: 73820
# Val: 47270
# Prueba: 52980

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

chp_train = X_train[[f"p{i}_champion_id" for i in range(1,6)]].copy()
chp_val = X_val[[f"p{i}_champion_id" for i in range(1,6)]].copy()
chp_test = X_test[[f"p{i}_champion_id" for i in range(1,6)]].copy()

X_train = X_train.drop((f"p{i}_champion_id" for i in range(1,6)),axis=1)
X_val = X_val.drop((f"p{i}_champion_id" for i in range(1,6)),axis=1)
X_test = X_test.drop((f"p{i}_champion_id" for i in range(1,6)),axis=1)

X_train_prep = pd.DataFrame(
    scaler.fit_transform(X_train),
    columns=X_train.columns,
    index=X_train.index)

X_val_prep = pd.DataFrame(
    scaler.fit_transform(X_val),
    columns=X_val.columns,
    index=X_val.index)

X_test_prep = pd.DataFrame(
    scaler.fit_transform(X_test),
    columns=X_test.columns,
    index=X_test.index)

for i in range(1,6):
    X_train_prep.insert(1+(16*(i-1)),(f"p{i}_champion_id"),chp_train[f"p{i}_champion_id"])
    X_val_prep.insert(1+(16*(i-1)),(f"p{i}_champion_id"),chp_val[f"p{i}_champion_id"])
    X_test_prep.insert(1+(16*(i-1)),(f"p{i}_champion_id"),chp_test[f"p{i}_champion_id"])

# %%
X_train_prep.head()
# Out:
#    side p1_champion_id  p1_champion_last30_winrate  p1_kills  p1_deaths  \
# 0   1.0            119                   -1.100477  0.131863   0.074523
# 1  -1.0             21                   -1.100477  1.416102   1.100875
# 2   1.0            138                   -1.100477 -0.724297  -0.438654
# 3  -1.0            119                   -1.100477 -0.724297   0.074523
# 4   1.0             37                   -1.100477 -0.724297  -0.951830
#
#    p1_pentakill  p1_assist    p1_dpm   p1_cspm   p1_vspm  ...  p5_xpat15  \
# 0     -0.028282   2.171872 -0.047952 -0.658826  0.508362  ...   0.302072
# 1     -0.028282   0.800695  0.855966  0.904908  0.204514  ...   0.583836
# 2     -0.028282   1.623401 -0.303501  1.610997  0.204514  ...   0.583836
# 3     -0.028282   0.252224 -0.082128  0.497947  0.508362  ...   0.302072
# 4     -0.028282  -0.570482  0.232843  0.857442  0.220387  ...   0.789759
#
#     dragons    barons   heralds    towers  goldat10  goldat15    xpat10  \
# 0 -0.791633 -0.918071 -0.911652 -1.045967  0.051586 -0.011320  0.343358
# 1  0.600220  3.206321 -0.911652  1.355176  0.244388  0.352293  0.478172
# 2 -0.791633 -0.918071 -0.911652  1.088382  0.244388  0.352293  0.478172
# 3  0.600220  1.831524 -0.911652  0.554795  0.051586 -0.011320  0.343358
# 4 -0.791633 -0.918071 -0.911652 -0.779173 -0.203742 -0.197612  0.300297
#
#      xpat15  wins_vs_opponent
# 0  0.386570         -0.750849
# 1  0.675136         -0.750849
# 2  0.675136         -0.479289
# 3  0.386570         -0.750849
# 4  0.431013         -0.750849
#
# [5 rows x 85 columns]

# %%
X_train_prep.describe()
# Out:
#                side  p1_champion_last30_winrate      p1_kills     p1_deaths  \
# count  73820.000000                7.382000e+04  7.382000e+04  7.382000e+04
# mean       0.000000                2.340883e-16 -5.544197e-17 -8.624306e-17
# std        1.000007                1.000007e+00  1.000007e+00  1.000007e+00
# min       -1.000000               -1.100477e+00 -1.152377e+00 -1.465007e+00
# 25%       -1.000000               -1.100477e+00 -7.242968e-01 -9.518305e-01
# 50%        0.000000                1.041404e-01 -2.962170e-01  7.452251e-02
# 75%        1.000000                7.091622e-01  5.599425e-01  5.876990e-01
# max        1.000000                1.612625e+00  8.693458e+00  7.258993e+00
#
#        p1_pentakill     p1_assist        p1_dpm       p1_cspm       p1_vspm  \
# count  7.382000e+04  7.382000e+04  7.382000e+04  7.351800e+04  7.382000e+04
# mean  -1.463052e-17  8.624306e-17 -2.279281e-16  1.583494e-15  2.032872e-16
# std    1.000007e+00  1.000007e+00  1.000007e+00  1.000007e+00  1.000007e+00
# min   -2.828216e-02 -1.393188e+00 -2.592464e+00 -6.141890e+00 -3.779563e+00
# 25%   -2.828216e-02 -8.447169e-01 -7.162052e-01 -6.717277e-01 -6.482541e-01
# 50%   -2.828216e-02 -2.201090e-02 -1.428937e-01 -3.507212e-03 -3.986121e-02
# 75%   -2.828216e-02  5.264598e-01  5.805961e-01  6.631802e-01  5.503534e-01
# max    3.535798e+01  6.285402e+00  6.409400e+00  4.387890e+00  8.573172e+00
#
#        p1_firstblood  ...     p5_xpat15       dragons        barons  \
# count   7.357800e+04  ...  7.382000e+04  7.382000e+04  7.382000e+04
# mean   -6.180480e-18  ...  2.710496e-16  1.170442e-16 -1.078038e-16
# std     1.000007e+00  ...  1.000007e+00  1.000007e+00  1.000007e+00
# min    -3.059821e-01  ... -3.534099e+00 -1.487559e+00 -9.180712e-01
# 25%    -3.059821e-01  ... -6.758100e-01 -7.916329e-01 -9.180712e-01
# 50%    -3.059821e-01  ... -2.835216e-02 -9.570640e-02  4.567263e-01
# 75%    -3.059821e-01  ...  5.855484e-01  6.002201e-01  4.567263e-01
# max     3.268165e+00  ...  8.380703e+00  4.079853e+00  7.330713e+00
#
#             heralds        towers      goldat10      goldat15        xpat10  \
# count  7.382000e+04  7.382000e+04  7.382000e+04  7.382000e+04  7.382000e+04
# mean  -2.464088e-17  7.161254e-17 -1.767983e-15  6.468230e-16  2.229999e-15
# std    1.000007e+00  1.000007e+00  1.000007e+00  1.000007e+00  1.000007e+00
# min   -9.116517e-01 -1.579554e+00 -4.605952e+00 -4.185672e+00 -7.096957e+00
# 25%   -9.116517e-01 -1.045967e+00 -6.701446e-01 -6.878863e-01 -6.038879e-01
# 50%    4.515416e-01  2.880013e-01 -1.273469e-01 -1.207367e-01  1.019298e-01
# 75%    4.515416e-01  8.215887e-01  5.359561e-01  5.647507e-01  6.472958e-01
# max    1.814735e+00  1.355176e+00  9.067731e+00  8.357058e+00  7.878407e+00
#
#              xpat15  wins_vs_opponent
# count  7.382000e+04      7.382000e+04
# mean  -1.712541e-15      4.928175e-17
# std    1.000007e+00      1.000007e+00
# min   -6.413461e+00     -7.508491e-01
# 25%   -6.401639e-01     -7.508491e-01
# 50%    5.914816e-02     -4.792885e-01
# 75%    6.419082e-01      3.353931e-01
# max    5.283459e+00      7.395967e+00
#
# [8 rows x 80 columns]

# %% [markdown]
# # Definición del modelo

# %%
print(X_train_prep.shape)
print(y_train_prep.unique())
# Out:
# (73820, 85)
# [0 1]

# %% [raw]
# num_features = len(X_train_prep.columns)
#
# network = Sequential([
#     # 1. Capa de Entrada (Dependerá de cuántas columnas numéricas te queden)
#     Input(shape=(num_features,)),
#
#     # 2. Primer Bloque Oculto
#     Dense(128, activation='relu'),
#     BatchNormalization(),
#     Dropout(0.3),
#
#     # 3. Segundo Bloque Oculto
#     Dense(64, activation='relu'),
#     BatchNormalization(),
#     Dropout(0.2),
#
#     # 4. Tercer Bloque Oculto
#     Dense(32, activation='relu'),
#     Dropout(0.2),
#
#     # 5. Capa de Salida
#     Dense(1, activation='sigmoid')
# ])

# %% [raw]
# network.summary()

# %% [raw]
# network.compile(loss='binary_crossentropy',
#                 optimizer='adam',
#                 metrics=['accuracy', AUC(name='auc')])

# %% [raw]
# history = network.fit(X_train_prep,
#                       y_train_prep,
#                       epochs=150,
#                       validation_data=(X_val_prep, y_val_prep))

# %% [markdown]
# # Modelo solo con las columnas del equipo

# %%
columnas_equipo = ["side","dragons","barons","heralds","towers","goldat10","goldat15","xpat10","xpat15","wins_vs_opponent"]

# %%
X_train_team = X_train_prep[columnas_equipo_mudas]
X_val_team = X_val_prep[columnas_equipo_mudas]
X_test_team = X_test_prep[columnas_equipo_mudas]

# %%
num_features = len(X_train_team.columns)

network_team = Sequential([
    # 1. Capa de Entrada (Dependerá de cuántas columnas numéricas te queden)
    Input(shape=(num_features,)), 
    
    # 2. Primer Bloque Oculto
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    
    # 3. Segundo Bloque Oculto
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    
    # 4. Tercer Bloque Oculto
    Dense(32, activation='relu'),
    Dropout(0.2),
    
    # 5. Capa de Salida
    Dense(1, activation='sigmoid') 
])

# %%
network_team.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 128)                 │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,033 (47.00 KB)
#  Trainable params: 11,649 (45.50 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
network_team.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy', AUC(name='auc')])

# %%
history = network_team.fit(X_train_team, 
                      y_train_prep, 
                      epochs=50, 
                      validation_data=(X_val_team, y_val_prep))
# Out:
# Epoch 1/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6743 - auc: 0.7396 - loss: 0.6021 - val_accuracy: 0.6759 - val_auc: 0.7515 - val_loss: 0.5864
# Epoch 2/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6849 - auc: 0.7551 - loss: 0.5864 - val_accuracy: 0.6739 - val_auc: 0.7507 - val_loss: 0.5871
# Epoch 3/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6868 - auc: 0.7559 - loss: 0.5858 - val_accuracy: 0.6755 - val_auc: 0.7506 - val_loss: 0.5866
# Epoch 4/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6885 - auc: 0.7572 - loss: 0.5845 - val_accuracy: 0.6758 - val_auc: 0.7518 - val_loss: 0.5854
# Epoch 5/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6891 - auc: 0.7575 - loss: 0.5843 - val_accuracy: 0.6747 - val_auc: 0.7516 - val_loss: 0.5869
# Epoch 6/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6879 - auc: 0.7583 - loss: 0.5834 - val_accuracy: 0.6739 - val_auc: 0.7526 - val_loss: 0.5863
# Epoch 7/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6894 - auc: 0.7578 - loss: 0.5835 - val_accuracy: 0.6729 - val_auc: 0.7510 - val_loss: 0.5876
# Epoch 8/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6877 - auc: 0.7589 - loss: 0.5827 - val_accuracy: 0.6740 - val_auc: 0.7532 - val_loss: 0.5846
# Epoch 9/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6884 - auc: 0.7598 - loss: 0.5821 - val_accuracy: 0.6740 - val_auc: 0.7527 - val_loss: 0.5858
# Epoch 10/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6891 - auc: 0.7594 - loss: 0.5825 - val_accuracy: 0.6745 - val_auc: 0.7519 - val_loss: 0.5857
# Epoch 11/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6897 - auc: 0.7599 - loss: 0.5816 - val_accuracy: 0.6765 - val_auc: 0.7517 - val_loss: 0.5877
# Epoch 12/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6891 - auc: 0.7597 - loss: 0.5817 - val_accuracy: 0.6766 - val_auc: 0.7521 - val_loss: 0.5856
# Epoch 13/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6900 - auc: 0.7604 - loss: 0.5813 - val_accuracy: 0.6743 - val_auc: 0.7525 - val_loss: 0.5851
# Epoch 14/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6895 - auc: 0.7607 - loss: 0.5808 - val_accuracy: 0.6785 - val_auc: 0.7525 - val_loss: 0.5847
# Epoch 15/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6895 - auc: 0.7603 - loss: 0.5813 - val_accuracy: 0.6742 - val_auc: 0.7528 - val_loss: 0.5853
# Epoch 16/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6886 - auc: 0.7604 - loss: 0.5810 - val_accuracy: 0.6750 - val_auc: 0.7525 - val_loss: 0.5859
# Epoch 17/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6910 - auc: 0.7614 - loss: 0.5801 - val_accuracy: 0.6737 - val_auc: 0.7518 - val_loss: 0.5858
# Epoch 18/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6882 - auc: 0.7603 - loss: 0.5810 - val_accuracy: 0.6752 - val_auc: 0.7523 - val_loss: 0.5856
# Epoch 19/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6909 - auc: 0.7615 - loss: 0.5800 - val_accuracy: 0.6734 - val_auc: 0.7520 - val_loss: 0.5851
# Epoch 20/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6904 - auc: 0.7612 - loss: 0.5801 - val_accuracy: 0.6734 - val_auc: 0.7515 - val_loss: 0.5863
# Epoch 21/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6892 - auc: 0.7614 - loss: 0.5794 - val_accuracy: 0.6735 - val_auc: 0.7521 - val_loss: 0.5858
# Epoch 22/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6903 - auc: 0.7618 - loss: 0.5795 - val_accuracy: 0.6744 - val_auc: 0.7519 - val_loss: 0.5858
# Epoch 23/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6896 - auc: 0.7618 - loss: 0.5793 - val_accuracy: 0.6736 - val_auc: 0.7521 - val_loss: 0.5856
# Epoch 24/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.6914 - auc: 0.7620 - loss: 0.5793 - val_accuracy: 0.6748 - val_auc: 0.7518 - val_loss: 0.5852
# Epoch 25/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6899 - auc: 0.7619 - loss: 0.5791 - val_accuracy: 0.6739 - val_auc: 0.7515 - val_loss: 0.5872
# Epoch 26/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6909 - auc: 0.7620 - loss: 0.5792 - val_accuracy: 0.6748 - val_auc: 0.7516 - val_loss: 0.5864
# Epoch 27/50
# 2307/2307 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6903 - auc: 0.7623 - loss: 0.5788 - val_accuracy: 0.6765 - val_auc: 0.7522 - val_loss: 0.5855
# Epoch 28/50
# 1192/2307 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6919 - auc: 0.7626 - loss: 0.5783
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 history = network_team.fit(X_train_team,
#       2                       y_train_prep,
#       3                       epochs=50,
#       4                       validation_data=(X_val_team, y_val_prep))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(10, 7))
plt.grid(True)
plt.gca().set_ylim(0, 1.2)
plt.xlabel("epochs")
plt.show()

# %%
test_loss, test_acc, test_prec = network_team.evaluate(X_test_team, y_test_prep)
# Out:
# 1656/1656 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9687 - auc: 0.9904 - loss: 0.0997

# %%
print('test_acc:', test_acc)
print('test_prec:', test_prec)
print('test_loss:', test_loss)
# Out:
# test_acc: 0.9686862826347351
# test_prec: 0.9904482364654541
# test_loss: 0.09966385364532471
