# %% [markdown]
# # Import libs and data

# %%
import numpy as np
import pandas as pd
from extract_by_teams import *
from predecir_partida import *
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785671123.765973   14926 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1785671123.766466   14926 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1785671123.806268   14926 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785671125.490657   14926 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1785671125.491010   14926 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
train_set = pd.read_csv("../Data/Net/train_data2.csv")
val_set = pd.read_csv("../Data/Net/val_data2.csv")
test_set = pd.read_csv("../Data/Net/test_data2.csv")

complete_set = pd.concat([train_set,val_set,test_set], ignore_index=True)
lista_columnas =["gameid","side","goldat10","goldat15","xpat10","xpat15","avg_dragons_team","avg_barons_team","avg_heralds_team","avg_towers_team","avg_dragons_vs_opp","avg_barons_vs_opp","avg_heralds_vs_opp","avg_towers_vs_opp","wins_vs_opponent"]
complete_set = complete_set[lista_columnas]
complete_set.to_csv("../Data/Net/complete_set.csv",index=False)

# %%
complete_set = pd.read_csv("../Data/Net/complete_set.csv")
lista_columnas =["side","goldat10","goldat15","xpat10","xpat15","avg_dragons_team","avg_barons_team","avg_heralds_team","avg_towers_team","avg_dragons_vs_opp","avg_barons_vs_opp","avg_heralds_vs_opp","avg_towers_vs_opp","wins_vs_opponent"]
complete_set = complete_set[lista_columnas]
scaler = StandardScaler()

complete_set = pd.DataFrame(
    scaler.fit_transform(complete_set),
    columns=complete_set.columns,
    index=complete_set.index)

# %%
model = keras.models.load_model("../Data/Model/Neuronal_net.keras")
# Out:
# E0000 00:00:1785671129.973229   14926 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
team_a,team_b = "LNG Esports","Rare Atom"

# %%
team_df = extraer_enfrentamientos(complete_set,team_a,team_b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 team_df = extraer_enfrentamientos(complete_set,team_a,team_b)
#
# File ~/Documentos/GitHub/Lol-Winrate-calc/Neuronal net/extract_by_teams.py:8, in extraer_enfrentamientos(df, team_a, team_b)
#       2 """
#       3 Extrae todas las filas de enfrentamientos entre team_a y team_b.
#       4 Usa operaciones vectorizadas de pandas (muy rápido).
#       5 """
#       6 # Paso 1: Encontrar los gameid donde jugaron AMBOS equipos
#       7 # groupby agrupa por gameid, y apply(set) crea un conjunto con los 2 equipos
# ----> 8 teams_por_game = df.groupby('gameid')['team'].apply(set)
#      10 # Filtramos los gameid donde están team_a Y team_b
#      11 gameids_validos = teams_por_game[
#      12     teams_por_game.apply(lambda equipos: team_a in equipos and team_b in equipos)
#      13 ].index
#
# File /opt/anaconda/lib/python3.13/site-packages/pandas/core/frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# File /opt/anaconda/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1328 self.dropna = dropna
#    1330 if grouper is None:
# -> 1331     grouper, exclusions, obj = get_grouper(
#    1332         obj,
#    1333         keys,
#    1334         axis=axis,
#    1335         level=level,
#    1336         sort=sort,
#    1337         observed=False if observed is lib.no_default else observed,
#    1338         dropna=self.dropna,
#    1339     )
#    1341 if observed is lib.no_default:
#    1342     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File /opt/anaconda/lib/python3.13/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'gameid'

# %%
team_df

# %%
simular_partida(team_df.iloc[-1],model,scaler)
