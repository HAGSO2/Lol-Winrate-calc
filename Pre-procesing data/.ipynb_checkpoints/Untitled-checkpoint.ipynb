# %%
pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting shap
#   Downloading shap-0.52.0-cp312-abi3-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: numpy>=2 in c:\users\agarc\appdata\roaming\python\python313\site-packages (from shap) (2.3.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from shap) (1.7.2)
# Requirement already satisfied: pandas in c:\users\agarc\appdata\roaming\python\python313\site-packages (from shap) (3.0.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\programdata\anaconda3\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\programdata\anaconda3\lib\site-packages (from shap) (25.0)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in c:\programdata\anaconda3\lib\site-packages (from shap) (0.62.1)
# Requirement already satisfied: llvmlite in c:\programdata\anaconda3\lib\site-packages (from shap) (0.45.1)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from shap) (3.1.1)
# Requirement already satisfied: colorama in c:\users\agarc\appdata\roaming\python\python313\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\agarc\appdata\roaming\python\python313\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\agarc\appdata\roaming\python\python313\site-packages (from pandas->shap) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\agarc\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->shap) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)
# Downloading shap-0.52.0-cp312-abi3-win_amd64.whl (499 kB)
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, shap
#
#    -------------------- ------------------- 1/2 [shap]
#    -------------------- ------------------- 1/2 [shap]
#    ---------------------------------------- 2/2 [shap]
#
# Successfully installed shap-0.52.0 slicer-0.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xgboost
#   Downloading xgboost-3.3.0-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\agarc\appdata\roaming\python\python313\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.16.3)
# Downloading xgboost-3.3.0-py3-none-win_amd64.whl (69.5 MB)
#    ---------------------------------------- 0.0/69.5 MB ? eta -:--:--
#    -------- ------------------------------- 15.5/69.5 MB 92.1 MB/s eta 0:00:01
#    ------------------ --------------------- 32.5/69.5 MB 87.1 MB/s eta 0:00:01
#    ------------------------------- -------- 55.3/69.5 MB 97.6 MB/s eta 0:00:01
#    ---------------------------------------  69.5/69.5 MB 91.0 MB/s eta 0:00:01
#    ---------------------------------------- 69.5/69.5 MB 72.1 MB/s  0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
año = "2024"
df = pd.read_csv(f"../Data/Raw Data/{año}_LoL_esports_match_data_from_OraclesElixir_preview.csv",low_memory=False)

# %%
print(df.info(True))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 165 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    gameid                    str
#  1    datacompleteness          str
#  2    url                       str
#  3    league                    str
#  4    year                      int64
#  5    split                     float64
#  6    playoffs                  int64
#  7    date                      str
#  8    game                      int64
#  9    patch                     float64
#  10   participantid             int64
#  11   side                      str
#  12   position                  str
#  13   playername                str
#  14   playerid                  str
#  15   teamname                  str
#  16   teamid                    str
#  17   firstPick                 int64
#  18   champion                  str
#  19   ban1                      str
#  20   ban2                      str
#  21   ban3                      str
#  22   ban4                      str
#  23   ban5                      str
#  24   pick1                     str
#  25   pick2                     str
#  26   pick3                     str
#  27   pick4                     str
#  28   pick5                     str
#  29   gamelength                int64
#  30   result                    int64
#  31   kills                     int64
#  32   deaths                    int64
#  33   assists                   int64
#  34   teamkills                 int64
#  35   teamdeaths                int64
#  36   doublekills               float64
#  37   triplekills               float64
#  38   quadrakills               float64
#  39   pentakills                float64
#  40   firstblood                float64
#  41   firstbloodkill            float64
#  42   firstbloodassist          float64
#  43   firstbloodvictim          float64
#  44   team kpm                  float64
#  45   ckpm                      float64
#  46   firstdragon               float64
#  47   dragons                   float64
#  48   opp_dragons               float64
#  49   elementaldrakes           float64
#  50   opp_elementaldrakes       float64
#  51   infernals                 float64
#  52   mountains                 float64
#  53   clouds                    float64
#  54   oceans                    float64
#  55   chemtechs                 float64
#  56   hextechs                  float64
#  57   dragons (type unknown)    float64
#  58   elders                    float64
#  59   opp_elders                float64
#  60   firstherald               float64
#  61   heralds                   float64
#  62   opp_heralds               float64
#  63   void_grubs                float64
#  64   opp_void_grubs            float64
#  65   firstbaron                float64
#  66   barons                    float64
#  67   opp_barons                float64
#  68   atakhans                  float64
#  69   opp_atakhans              float64
#  70   firsttower                float64
#  71   towers                    float64
#  72   opp_towers                float64
#  73   firstmidtower             float64
#  74   firsttothreetowers        float64
#  75   turretplates              float64
#  76   opp_turretplates          float64
#  77   inhibitors                float64
#  78   opp_inhibitors            float64
#  79   damagetochampions         int64
#  80   dpm                       float64
#  81   damageshare               float64
#  82   damagetakenperminute      float64
#  83   damagemitigatedperminute  float64
#  84   damagetotowers            float64
#  85   wardsplaced               int64
#  86   wpm                       float64
#  87   wardskilled               int64
#  88   wcpm                      float64
#  89   controlwardsbought        int64
#  90   visionscore               int64
#  91   vspm                      float64
#  92   totalgold                 int64
#  93   earnedgold                int64
#  94   earned gpm                float64
#  95   earnedgoldshare           float64
#  96   goldspent                 int64
#  97   gspd                      float64
#  98   gpr                       float64
#  99   total cs                  float64
#  100  minionkills               float64
#  101  monsterkills              int64
#  102  monsterkillsownjungle     int64
#  103  monsterkillsenemyjungle   int64
#  104  cspm                      float64
#  105  goldat10                  float64
#  106  xpat10                    float64
#  107  csat10                    float64
#  108  opp_goldat10              float64
#  109  opp_xpat10                float64
#  110  opp_csat10                float64
#  111  golddiffat10              float64
#  112  xpdiffat10                float64
#  113  csdiffat10                float64
#  114  killsat10                 float64
#  115  assistsat10               float64
#  116  deathsat10                float64
#  117  opp_killsat10             float64
#  118  opp_assistsat10           float64
#  119  opp_deathsat10            float64
#  120  goldat15                  float64
#  121  xpat15                    float64
#  122  csat15                    float64
#  123  opp_goldat15              float64
#  124  opp_xpat15                float64
#  125  opp_csat15                float64
#  126  golddiffat15              float64
#  127  xpdiffat15                float64
#  128  csdiffat15                float64
#  129  killsat15                 float64
#  130  assistsat15               float64
#  131  deathsat15                float64
#  132  opp_killsat15             float64
#  133  opp_assistsat15           float64
#  134  opp_deathsat15            float64
#  135  goldat20                  float64
#  136  xpat20                    float64
#  137  csat20                    float64
#  138  opp_goldat20              float64
#  139  opp_xpat20                float64
#  140  opp_csat20                float64
#  141  golddiffat20              float64
#  142  xpdiffat20                float64
#  143  csdiffat20                float64
#  144  killsat20                 float64
#  145  assistsat20               float64
#  146  deathsat20                float64
#  147  opp_killsat20             float64
#  148  opp_assistsat20           float64
#  149  opp_deathsat20            float64
#  150  goldat25                  float64
#  151  xpat25                    float64
#  152  csat25                    float64
#  153  opp_goldat25              float64
#  154  opp_xpat25                float64
#  155  opp_csat25                float64
#  156  golddiffat25              float64
#  157  xpdiffat25                float64
#  158  csdiffat25                float64
#  159  killsat25                 float64
#  160  assistsat25               float64
#  161  deathsat25                float64
#  162  opp_killsat25             float64
#  163  opp_assistsat25           float64
#  164  opp_deathsat25            float64
# dtypes: float64(120), int64(23), str(22)
# memory usage: 60.6 KB
# None

# %%
from sklearn.preprocessing import LabelEncoder
df_model = df.copy()
#Filas innecesarias: gameid, datacompleteness, url, league, date, playername, teamname
df_model = df_model.drop(["gameid","datacompleteness","url","league","date","playername","teamname"],axis=1)
#Filas a convertir:side, position, playerid, teamname, champion, ban-5, pick-5
# ============================
# 1. SIDE -> bool (0 = Blue, 1 = Red)
# ============================

df_model["side"] = df_model["side"].map({
    "Blue": 0,
    "Red": 1
}).astype("bool")

# ============================
# 2. POSITION -> One-Hot
# ============================

df_model = pd.get_dummies(
    df_model,
    columns=["position"],
    prefix="position",
    dtype=bool
)

# ============================
# 3. Label Encoding
# ============================

encoder = LabelEncoder()

columnas_label = [
    "playerid",
    "teamid",
    "champion",
    "ban1",
    "ban2",
    "ban3",
    "ban4",
    "ban5",
    "pick1",
    "pick2",
    "pick3",
    "pick4",
    "pick5"
]

for col in columnas_label:
    if col in df_model.columns:
        df_model[col] = encoder.fit_transform(
            df_model[col].astype(str)
        )

#print(df_model.dtypes)
print(df_model.info(True))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 163 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    year                      int64
#  1    split                     float64
#  2    playoffs                  int64
#  3    game                      int64
#  4    patch                     float64
#  5    participantid             int64
#  6    side                      bool
#  7    playerid                  int64
#  8    teamid                    int64
#  9    firstPick                 int64
#  10   champion                  int64
#  11   ban1                      int64
#  12   ban2                      int64
#  13   ban3                      int64
#  14   ban4                      int64
#  15   ban5                      int64
#  16   pick1                     int64
#  17   pick2                     int64
#  18   pick3                     int64
#  19   pick4                     int64
#  20   pick5                     int64
#  21   gamelength                int64
#  22   result                    int64
#  23   kills                     int64
#  24   deaths                    int64
#  25   assists                   int64
#  26   teamkills                 int64
#  27   teamdeaths                int64
#  28   doublekills               float64
#  29   triplekills               float64
#  30   quadrakills               float64
#  31   pentakills                float64
#  32   firstblood                float64
#  33   firstbloodkill            float64
#  34   firstbloodassist          float64
#  35   firstbloodvictim          float64
#  36   team kpm                  float64
#  37   ckpm                      float64
#  38   firstdragon               float64
#  39   dragons                   float64
#  40   opp_dragons               float64
#  41   elementaldrakes           float64
#  42   opp_elementaldrakes       float64
#  43   infernals                 float64
#  44   mountains                 float64
#  45   clouds                    float64
#  46   oceans                    float64
#  47   chemtechs                 float64
#  48   hextechs                  float64
#  49   dragons (type unknown)    float64
#  50   elders                    float64
#  51   opp_elders                float64
#  52   firstherald               float64
#  53   heralds                   float64
#  54   opp_heralds               float64
#  55   void_grubs                float64
#  56   opp_void_grubs            float64
#  57   firstbaron                float64
#  58   barons                    float64
#  59   opp_barons                float64
#  60   atakhans                  float64
#  61   opp_atakhans              float64
#  62   firsttower                float64
#  63   towers                    float64
#  64   opp_towers                float64
#  65   firstmidtower             float64
#  66   firsttothreetowers        float64
#  67   turretplates              float64
#  68   opp_turretplates          float64
#  69   inhibitors                float64
#  70   opp_inhibitors            float64
#  71   damagetochampions         int64
#  72   dpm                       float64
#  73   damageshare               float64
#  74   damagetakenperminute      float64
#  75   damagemitigatedperminute  float64
#  76   damagetotowers            float64
#  77   wardsplaced               int64
#  78   wpm                       float64
#  79   wardskilled               int64
#  80   wcpm                      float64
#  81   controlwardsbought        int64
#  82   visionscore               int64
#  83   vspm                      float64
#  84   totalgold                 int64
#  85   earnedgold                int64
#  86   earned gpm                float64
#  87   earnedgoldshare           float64
#  88   goldspent                 int64
#  89   gspd                      float64
#  90   gpr                       float64
#  91   total cs                  float64
#  92   minionkills               float64
#  93   monsterkills              int64
#  94   monsterkillsownjungle     int64
#  95   monsterkillsenemyjungle   int64
#  96   cspm                      float64
#  97   goldat10                  float64
#  98   xpat10                    float64
#  99   csat10                    float64
#  100  opp_goldat10              float64
#  101  opp_xpat10                float64
#  102  opp_csat10                float64
#  103  golddiffat10              float64
#  104  xpdiffat10                float64
#  105  csdiffat10                float64
#  106  killsat10                 float64
#  107  assistsat10               float64
#  108  deathsat10                float64
#  109  opp_killsat10             float64
#  110  opp_assistsat10           float64
#  111  opp_deathsat10            float64
#  112  goldat15                  float64
#  113  xpat15                    float64
#  114  csat15                    float64
#  115  opp_goldat15              float64
#  116  opp_xpat15                float64
#  117  opp_csat15                float64
#  118  golddiffat15              float64
#  119  xpdiffat15                float64
#  120  csdiffat15                float64
#  121  killsat15                 float64
#  122  assistsat15               float64
#  123  deathsat15                float64
#  124  opp_killsat15             float64
#  125  opp_assistsat15           float64
#  126  opp_deathsat15            float64
#  127  goldat20                  float64
#  128  xpat20                    float64
#  129  csat20                    float64
#  130  opp_goldat20              float64
#  131  opp_xpat20                float64
#  132  opp_csat20                float64
#  133  golddiffat20              float64
#  134  xpdiffat20                float64
#  135  csdiffat20                float64
#  136  killsat20                 float64
#  137  assistsat20               float64
#  138  deathsat20                float64
#  139  opp_killsat20             float64
#  140  opp_assistsat20           float64
#  141  opp_deathsat20            float64
#  142  goldat25                  float64
#  143  xpat25                    float64
#  144  csat25                    float64
#  145  opp_goldat25              float64
#  146  opp_xpat25                float64
#  147  opp_csat25                float64
#  148  golddiffat25              float64
#  149  xpdiffat25                float64
#  150  csdiffat25                float64
#  151  killsat25                 float64
#  152  assistsat25               float64
#  153  deathsat25                float64
#  154  opp_killsat25             float64
#  155  opp_assistsat25           float64
#  156  opp_deathsat25            float64
#  157  position_bot              bool
#  158  position_jng              bool
#  159  position_mid              bool
#  160  position_sup              bool
#  161  position_team             bool
#  162  position_top              bool
# dtypes: bool(7), float64(120), int64(36)
# memory usage: 49.2 KB
# None

# %%
X_train = df_model.drop("result",axis=1)
y_train = df_model["result"]

# %%
from xgboost import XGBClassifier

modelo = XGBClassifier(random_state=42)
modelo.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Obtener importancia de las variables
importancias = modelo.feature_importances_

# Crear DataFrame
df_importancias = pd.DataFrame({
    "Variable": X_train.columns,
    "Importancia": importancias
})

# Ordenar
df_importancias = df_importancias.sort_values(
    by="Importancia",
    ascending=True
)

# Gráfico
plt.figure(figsize=(10,7))

plt.barh(
    df_importancias["Variable"],
    df_importancias["Importancia"]
)

plt.xlabel("Importancia")
plt.ylabel("Variable")
plt.title("Importancia de las variables del modelo XGBoost")

plt.tight_layout()
plt.show()

# %%
import shap
import matplotlib.pyplot as plt

explainer = shap.TreeExplainer(modelo)
shap_values = explainer.shap_values(X_train)

shap.summary_plot(
    shap_values,
    X_train,
    plot_type="bar"
)

# %%
import shap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

explainer = shap.TreeExplainer(modelo)
shap_values = explainer.shap_values(X_train)

# Importancia media absoluta
importancia = np.abs(shap_values).mean(axis=0)

df = pd.DataFrame({
    "Variable": X_train.columns,
    "Importancia": importancia
})

df = df.sort_values("Importancia")

plt.figure(figsize=(10,7))

plt.barh(df["Variable"], df["Importancia"])

plt.xlabel("Valor SHAP medio")
plt.ylabel("Variable")
plt.title("Importancia de variables según SHAP")

plt.tight_layout()
plt.show()
